# %% [markdown]
# # MODELING AND EXECUTION (WITHOUT TUNING)
#
# This notebook illustrates the process of:
# - Pre-processing of data collected
# - Trading Account Class creation and helper functions
# - Modeling **(WITHOUT TUNING)** for single company run
# - Execution and backtesting of Long/Short Term strategies
# - Auditing transactions and portfolio execution results
#
# This notebook contain codes for modeling of one company at a time. All required plots and CSV files will be generated and automatically saved to their respective folders for subsequent evaluation. Although a function loop may seems to be more efficient to model for more than one company. The implementation within a jupyter notebook environment will not be practical due to the kernel needing to be reset after every model trial to avoid continuous trying from the weights saved from the previous run of another company. Repeatedly initiating multiple and separate models by uniques company names will also cause a backlog hogging of memory. At least this is the case for our environment setup and using Google Chrome browser.
#
# An alternative is to build a batch file that calls for a .py file from command line. Although we have done this too to speed up the model tuning process, it does not provide the instant visualization that would help to quickly visualize any issues. Therefore, we shall be using this notebook to run each company individually for the output/results.
#
# However, do note that the single company selected randomly (CSCO) to run here will be used to explain the logic/process employed along with the matching visualization. Should you decide to run with another company, the visualization will not match the textual description of the process.
#
# **It is also strongly recommended that you read the IMPORTANT VARIABLES SETTINGS section before attempting to run this notebook.**

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import math
import datetime

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.optimizers import Adam

from keras.callbacks import EarlyStopping
from keras import backend
from keras.models import model_from_json

# setting some parameters
pd.options.display.max_columns = 50
pd.options.display.max_rows = 100

# fix random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# enable interactive toolbar
#%matplotlib widget

# to return to normal if interactive maps are not working
#%matplotlib inline

# %%
# checking versions
print('tensorflow version =', tf.__version__) # version 2.2 works with GPU, other versions may have issues
print('pandas version =', pd.__version__) # version 1.2.0 and below work
print('numpy version =', np.__version__) # version 1.19.5 and below work
print('keras version = ', keras.__version__) # version 2.3.0-tf works with GPU, other versions may have issues
# Out:
# tensorflow version = 2.3.0
# pandas version = 1.2.0
# numpy version = 1.18.5
# keras version =  2.4.0

# %%
# test to confirm GPU is available
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
else:
    print('This version of Tensorflow or Keras is not working with GPUs. Expect slower speed.')
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data import and pre-processing
#
# We shall import the data files from the data collection and EDA stage for pre-processing.

# %% [markdown]
# ### Prices data

# %%
# reading in prices retrieved from yfinance
price_data = pd.read_csv('datasets/backups/cleaned_daily_adj_prices_df.csv')
print(price_data.shape)
price_data.head()
# Out:
# (154687, 12)
#          Date       Open       High        Low      Close      Volume  \
# 0  2013-01-02  24.597448  24.935559  24.019845  24.738327  13767900.0
# 1  2013-01-03  24.653801  24.653801  24.062110  24.534056  16739300.0
# 2  2013-01-04  24.386131  24.576318  24.125506  24.224121  21372100.0
# 3  2013-01-07  24.055067  24.970780  24.055067  24.273428  17897100.0
# 4  2013-01-08  24.153686  24.400223  23.498599  23.745136  17863300.0
#
#    Dividends  Stock Splits ticker         name      sector  \
# 0        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 1        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 2        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 3        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 4        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
#
#                        industry
# 0  Drug Manufacturers - General
# 1  Drug Manufacturers - General
# 2  Drug Manufacturers - General
# 3  Drug Manufacturers - General
# 4  Drug Manufacturers - General

# %%
# set Date to datetime
price_data['Date'] = pd.to_datetime(price_data['Date'])

# %%
print(len(price_data.ticker.unique()))
price_data.ticker.unique()
# Out:
# 20
# array(['ABBV', 'CAG', 'CSCO', 'GSK', 'LMT', 'MRK', 'RCI', 'TRP', 'VALE',
#        'VZ', 'ABT', 'AJG', 'DG', 'FBHS', 'FMC', 'LDOS', 'MGA', 'NEM',
#        'PWR', 'SAP'], dtype=object)

# %% [markdown]
# ### News data

# %%
# reading in news sentiment
senti_mean_df = pd.read_csv('datasets/backups/news_senti.csv')
print(senti_mean_df.shape)
senti_mean_df.head()
# Out:
# (1088, 4)
#   ticker        date  compound Interpretation
# 0   ABBV  2020-11-24   0.18060       Positive
# 1   ABBV  2020-11-25   0.33260       Positive
# 2   ABBV  2020-11-27   0.12755       Positive
# 3   ABBV  2020-11-28   0.62490       Positive
# 4   ABBV  2020-11-29   0.00000        Neutral

# %%
# set Date to datetime
senti_mean_df['date'] = pd.to_datetime(senti_mean_df['date'])

# %%
senti_mean_df.ticker.unique()
# Out:
# array(['ABBV', 'CAG', 'CSCO', 'GSK', 'LMT', 'MRK', 'RCI', 'TRP', 'VALE',
#        'VZ', 'ABT', 'AJG', 'DG', 'FBHS', 'FMC', 'LDOS', 'MGA', 'NEM',
#        'PWR', 'SAP'], dtype=object)

# %% [markdown]
# ### Analyst's recommendations data

# %%
# read analyst recom data
analyst_recom_df = pd.read_csv('datasets/backups/cleaned_complete_scrape_analyst_recom.csv')
print(analyst_recom_df.shape)
analyst_recom_df.head()
# Out:
# (400, 5)
#          date recom_type             source ticker  recom_type_ordinal
# 0  2020-11-10    Resumed          Bernstein   ABBV                   4
# 1  2020-09-29  Initiated          Berenberg   ABBV                   2
# 2  2020-06-23    Upgrade  Atlantic Equities   ABBV                   5
# 3  2020-06-09    Upgrade     Wolfe Research   ABBV                   5
# 4  2020-06-02    Upgrade              Argus   ABBV                   5

# %%
# convert datetime
analyst_recom_df['date'] = analyst_recom_df['date'].astype('datetime64')
analyst_recom_df.dtypes
# Out:
# date                  datetime64[ns]
# recom_type                    object
# source                        object
# ticker                        object
# recom_type_ordinal             int64
# dtype: object

# %%
# sort and reset index
analyst_recom_df.sort_values(by='date', inplace=True)
analyst_recom_df.reset_index(drop=True, inplace=True)
analyst_recom_df.head()
# Out:
#         date  recom_type            source ticker  recom_type_ordinal
# 0 2015-10-23  Reiterated          Barclays    RCI                   3
# 1 2015-12-04   Initiated           Goldman    RCI                   2
# 2 2015-12-11     Upgrade     TD Securities    RCI                   5
# 3 2015-12-17   Downgrade    Morgan Stanley    RCI                   1
# 4 2016-04-19  Reiterated  RBC Capital Mkts    RCI                   3

# %% [markdown]
# ### Introducing Technical Indicators
#
# The following technical indicators are added to the data set and there are many more that could be added if the use has clear understanding of how those indicators work. Having more will increase the complexity of the model and computationally expensive for the scope of this project.
#
# **Momentum indicators**
#
# 1. **SMA20** - A simple moving average (SMA) calculates the average of a selected range of prices, usually closing prices, by the number of periods in that range. In this case, we are using the 20 periods moving average.
#
# 2. **RSI14** - The relative strength index (RSI) is a momentum indicator used in technical analysis that measures the magnitude of recent price changes to evaluate overbought or oversold conditions in the price of a stock or other asset.
#
# 3. **MOM5** - The Momentum is a measurement of the acceleration and deceleration of prices. It indicates if prices are increasing at an increasing rate or decreasing at a decreasing rate. The Momentum function can be applied to the price, or to any other data series. In this case, we are using the 5 periods momentum.
#
# **Volume indicators**
#
# 1. **OBV** - On-balance volume (OBV), a momentum indicator that measures positive and negative volume flow.
#
# **Volatility indicators**
#
# 1. **ATR14** - Average true range (ATR) is a market volatility indicator used in technical analysis. It is typically derived from the 14-day simple moving average of a series of true range indicators.

# %%
import talib as ta

# %%
# adding technical indicators to the price dataframe

# momentum indicators
price_data['SMA20'] = ta.SMA(price_data['Close'], timeperiod=20)
price_data['RSI14'] = ta.RSI(price_data['Close'], timeperiod=14)
price_data['MOM5'] = ta.MOM(price_data['Close'], timeperiod=5)

# volume indicators
price_data['OBV'] = ta.OBV(price_data['Close'], price_data['Volume'])

# volatility indicators
price_data['ATR14'] = ta.ATR(price_data['High'], price_data['Low'],
                             price_data['Close'], timeperiod=14)

# %%
# plot the technical indicators to confirm they are calculated
price_data.plot('Date', 'SMA20', kind='line', figsize=(9,3));
price_data.plot('Date', 'RSI14', kind='line', figsize=(9,3));
price_data.plot('Date', 'MOM5', kind='line', figsize=(9,3));
price_data.plot('Date', 'OBV', kind='line', figsize=(9,3));
price_data.plot('Date', 'ATR14', kind='line', figsize=(9,3));

# %% [markdown]
# ### Merge the data

# %%
# view shape of price data
print(price_data.shape)
price_data.columns
# Out:
# (154687, 17)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'ticker', 'name', 'sector', 'industry', 'SMA20',
#        'RSI14', 'MOM5', 'OBV', 'ATR14'],
#       dtype='object')

# %%
# view shape of analyst data
print(analyst_recom_df.shape)
analyst_recom_df.columns
# Out:
# (400, 5)
# Index(['date', 'recom_type', 'source', 'ticker', 'recom_type_ordinal'], dtype='object')

# %%
# view shape of sentiment data
print(senti_mean_df.shape)
senti_mean_df.columns
# Out:
# (1088, 4)
# Index(['ticker', 'date', 'compound', 'Interpretation'], dtype='object')

# %%
# merge price and analyst data
price_ana_df = pd.merge(price_data, analyst_recom_df, how='left', left_on=['Date', 'ticker'], right_on=['date', 'ticker'])
print(price_ana_df.shape)
price_ana_df.head()
# Out:
# (154704, 21)
#         Date       Open       High        Low      Close      Volume  \
# 0 2013-01-02  24.597448  24.935559  24.019845  24.738327  13767900.0
# 1 2013-01-03  24.653801  24.653801  24.062110  24.534056  16739300.0
# 2 2013-01-04  24.386131  24.576318  24.125506  24.224121  21372100.0
# 3 2013-01-07  24.055067  24.970780  24.055067  24.273428  17897100.0
# 4 2013-01-08  24.153686  24.400223  23.498599  23.745136  17863300.0
#
#    Dividends  Stock Splits ticker         name      sector  \
# 0        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 1        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 2        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 3        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 4        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
#
#                        industry  SMA20  RSI14  MOM5         OBV  ATR14 date  \
# 0  Drug Manufacturers - General    NaN    NaN   NaN  13767900.0    NaN  NaT
# 1  Drug Manufacturers - General    NaN    NaN   NaN  -2971400.0    NaN  NaT
# 2  Drug Manufacturers - General    NaN    NaN   NaN -24343500.0    NaN  NaT
# 3  Drug Manufacturers - General    NaN    NaN   NaN  -6446400.0    NaN  NaT
# 4  Drug Manufacturers - General    NaN    NaN   NaN -24309700.0    NaN  NaT
#
#   recom_type source  recom_type_ordinal
# 0        NaN    NaN                 NaN
# 1        NaN    NaN                 NaN
# 2        NaN    NaN                 NaN
# 3        NaN    NaN                 NaN
# 4        NaN    NaN                 NaN

# %%
# merge price, analyst and sentiment data
price_ana_senti_df = pd.merge(price_ana_df, senti_mean_df, how='left', left_on=['Date', 'ticker'], right_on=['date', 'ticker'])
print(price_ana_senti_df.shape)
price_ana_senti_df.head()
# Out:
# (154704, 24)
#         Date       Open       High        Low      Close      Volume  \
# 0 2013-01-02  24.597448  24.935559  24.019845  24.738327  13767900.0
# 1 2013-01-03  24.653801  24.653801  24.062110  24.534056  16739300.0
# 2 2013-01-04  24.386131  24.576318  24.125506  24.224121  21372100.0
# 3 2013-01-07  24.055067  24.970780  24.055067  24.273428  17897100.0
# 4 2013-01-08  24.153686  24.400223  23.498599  23.745136  17863300.0
#
#    Dividends  Stock Splits ticker         name      sector  \
# 0        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 1        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 2        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 3        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
# 4        0.0           0.0   ABBV  AbbVie Inc.  Healthcare
#
#                        industry  SMA20  RSI14  MOM5         OBV  ATR14 date_x  \
# 0  Drug Manufacturers - General    NaN    NaN   NaN  13767900.0    NaN    NaT
# 1  Drug Manufacturers - General    NaN    NaN   NaN  -2971400.0    NaN    NaT
# 2  Drug Manufacturers - General    NaN    NaN   NaN -24343500.0    NaN    NaT
# 3  Drug Manufacturers - General    NaN    NaN   NaN  -6446400.0    NaN    NaT
# 4  Drug Manufacturers - General    NaN    NaN   NaN -24309700.0    NaN    NaT
#
#   recom_type source  recom_type_ordinal date_y  compound Interpretation
# 0        NaN    NaN                 NaN    NaT       NaN            NaN
# 1        NaN    NaN                 NaN    NaT       NaN            NaN
# 2        NaN    NaN                 NaN    NaT       NaN            NaN
# 3        NaN    NaN                 NaN    NaT       NaN            NaN
# 4        NaN    NaN                 NaN    NaT       NaN            NaN

# %%
# view shape of fully merged data
print(price_ana_senti_df.shape)
price_ana_senti_df.sort_index(inplace=True)
price_ana_senti_df.columns
# Out:
# (154704, 24)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'ticker', 'name', 'sector', 'industry', 'SMA20',
#        'RSI14', 'MOM5', 'OBV', 'ATR14', 'date_x', 'recom_type', 'source',
#        'recom_type_ordinal', 'date_y', 'compound', 'Interpretation'],
#       dtype='object')

# %%
# checking NaN
price_ana_senti_df.isnull().sum()
# Out:
# Date                       0
# Open                       0
# High                       0
# Low                        0
# Close                      0
# Volume                     0
# Dividends                  0
# Stock Splits               0
# ticker                     0
# name                       0
# sector                     0
# industry                   0
# SMA20                     19
# RSI14                     14
# MOM5                       5
# OBV                        0
# ATR14                     14
# date_x                154304
# recom_type            154304
# source                154304
# recom_type_ordinal    154304
# date_y                153741
# compound              153741
# Interpretation        153741
# dtype: int64

# %% [markdown]
# **Note:** NaN values for `SMA20` `RSI14` `MOM5` `ATR14` are due to rolling calculations from past periods. These NaN are at the beginning of the data range for each company and will be imputed with zero before being pass into the modeling stage.
#
# `date_x` `recom_type` `source` `date_y` `Interpretation` NaN values do not need to be treated as these are not features that are to be used in modeling.
#
# `recom_type_ordinal` `compound` NaN values mean that there is no analyst recommendation and no news article sentiments respectively on those dates. These features will be used in modeling therefore they will be imputed with zero before being fed into modeling stage.

# %% [markdown]
# ## Modeling preparation
#
# Here we are training, debugging, evaluating and executing the model for one company in the portfolio. As the number of steps/cells to complete the cycle for one company is too long and complex, we will not be writing a loop through all the steps from here to end of the transactions audit steps. The steps below are meant for explaining the steps and logic behind.
#
# This time consuming process only need to be ran once for the selected company as there is a step to save the trained model. As long as there is no change in data size and data structure, we can easily load the saved model to test a different strategy. However, if the data and/or parameters change then the whole training cycle will have to be re-run.

# %% [markdown]
# ### IMPORTANT VARIABLES SETTINGS
#
# Key variables used throughout the code shall be defined here.
#
# **NOTE: THE EXPLANATION OF VISUALIZATION, EVALUATION, EXECUTION AND AUDITING PROCESSES ARE ALL BASED ON COMPANY "CSCO". IF YOU CHANGE THE COMPANY BELOW TO SOMETHING ELSE TO TEST THE CODES, THE EXPLANATION WILL NOT TALLY. BUT YOU CAN ALWAYS CHANGE BACK TO "CSCO" AND RE-RUN TO GET BACK THE VISUALIZATION TO MATCH THE EXPLANATION. IT WILL ONLY TAKE SOME TIME TO RE-RUN.**

# %%
# setting working directories
IMAGE_DIR = 'images/without_keras_tuning/'
TRANS_DIR = 'results/transactions/without_keras_tuning/'
PERF_DIR = 'results/performance/without_keras_tuning/'

# setting account starting balance and pred_pct_gain in daily prices before making a trade
acct_start_bal = 50000
pred_pct_gain = 1.05

# setting commission and fees (based on DBS OET US market fees)
comm_rate = 0.0015 # 0.15% on trans_amount each time but a min. of $18 will be imposed in the buy/sell functions
min_fees = 18

# setting the company to run
test_comp = 'CSCO'
one_comp_df = price_ana_senti_df[price_ana_senti_df['ticker'] == test_comp]

# %%
# keeping only the necessary columns
lstm_data = one_comp_df[['Date', 'Open', 'High', 'Low', 'Volume', 'Close',
                         'SMA20', 'RSI14', 'MOM5', 'OBV', 'ATR14',
                         'recom_type_ordinal', 'compound']]

# make all nan as zero
lstm_data = lstm_data.fillna(0)

# set data as the index
lstm_data.set_index('Date', drop=True, inplace=True)

# setting and partitioning train data boundary
lstm_data = lstm_data.loc['2000-01-01':'2021-01-05']
print('No of trading days available for training data =', lstm_data.shape[0])
# Out:
# No of trading days available for training data = 5286

# %%
# setting the number of periods to look back as train data
n_per_in  = 60
print(f'{n_per_in} periods look back for training')

# setting the number of periods in future to predict
n_per_out = 1
print(f'{n_per_out} period(s) prediction')

# setting the number of features
n_features = lstm_data.shape[1]
print(f'{n_features} features to train on')

# calculating number of sequences to train
print(f'Number of training sequences = {lstm_data.shape[0] / n_per_in}')
# Out:
# 60 periods look back for training
# 1 period(s) prediction
# 12 features to train on
# Number of training sequences = 88.1

# %% [markdown]
# ### Scaling data
#
# **StandardScaler** removes the mean and scales the data to unit variance. However, the outliers have an influence when computing the empirical mean and standard deviation. Note in particular that because the outliers on each feature have different magnitudes, the spread of the transformed data on each feature is very different: most of the data lie in the [-2, 4] range for the transformed median income feature while the same data is squeezed in the smaller [-0.2, 0.2] range for the transformed number of households. StandardScaler therefore cannot guarantee balanced feature scales in the presence of outliers.
#
# **MinMaxScaler** rescales the data set such that all feature values are in the range [0, 1]. However, this scaling compresses all inliers into the narrow range [0, 0.005] for the transformed number of households. Both StandardScaler and MinMaxScaler are very sensitive to the presence of outliers.
#
# **RobustScaler** is based on percentiles and are therefore not influenced by a few number of very large marginal outliers. Consequently, the resulting range of the transformed feature values is larger than for the previous scalers and, more importantly, are approximately similar: for both features most of the transformed values lie in a [-2, 3] range. Note that the outliers themselves are still present in the transformed data. If a separate outlier clipping is desirable, a non-linear transformation is required.
#
# **Decision** was to test all three scalers as majority of the literature research online could not conclude which scaler is the best for our project application context. Almost all literatures suggested to test all three and use the one with the best performance. In our context, we tested all three scalers and found that **MinMaxScaler** performed the best.

# %%
# Close Price Scaling, meant for inverse scaling CLose price at the end
close_sc = MinMaxScaler(feature_range=(0, 1))
close_sc.fit(lstm_data[['Close']])
# Out:
# MinMaxScaler()

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range=(0, 1))
lstm_data_scaled = pd.DataFrame(sc.fit_transform(lstm_data), columns=lstm_data.columns, index=lstm_data.index)
lstm_data_scaled.tail()
# Out:
#                 Open      High       Low    Volume     Close     SMA20  \
# Date
# 2020-12-29  0.701491  0.698056  0.718137  0.019506  0.708237  0.778704
# 2020-12-30  0.697311  0.694594  0.716455  0.018100  0.705267  0.779699
# 2020-12-31  0.690769  0.690585  0.711219  0.025360  0.710279  0.780610
# 2021-01-04  0.696028  0.688577  0.702648  0.041976  0.702232  0.780829
# 2021-01-05  0.684485  0.683066  0.703213  0.030120  0.702607  0.780783
#
#                RSI14      MOM5       OBV     ATR14  recom_type_ordinal  \
# Date
# 2020-12-29  0.638291  0.569508  0.832943  0.150188                 0.0
# 2020-12-30  0.606674  0.570795  0.831215  0.148213                 0.0
# 2020-12-31  0.642222  0.595662  0.833578  0.147592                 0.0
# 2021-01-04  0.557442  0.570216  0.829762  0.154460                 0.0
# 2021-01-05  0.560448  0.554789  0.832541  0.153707                 0.0
#
#             compound
# Date
# 2020-12-29  0.646332
# 2020-12-30  0.395722
# 2020-12-31  0.336515
# 2021-01-04  1.000000
# 2021-01-05  0.336515

# %%
# checking ordinal scale
lstm_data_scaled.recom_type_ordinal.unique()
# Out:
# array([0. , 0.6, 0.4, 0.2, 0.8, 1. ])

# %%
# checking compound scale
# if the result is 0, that means no news analyzed in the data period for this company
lstm_data_scaled.compound.unique()
# Out:
# array([0.33651537, 0.44700376, 0.45587239, 0.58021802, 0.44851266,
#        0.70862844, 0.51828129, 0.        , 0.83155755, 0.64633245,
#        0.39572171, 1.        ])

# %% [markdown]
# ### Helper functions

# %%
# function to split the data set into no. of periods to step back and no. of periods in future to predict
def split_sequence(seq, n_steps_in, n_steps_out):
    X, y = [], []
    
    for i in range(len(seq)):
        # find end of current sequence
        end = i + n_steps_in
        out_end = end + n_steps_out
        
        # break if exceed dataset length
        if out_end > len(seq):
            break
        
        # splitting the sequences into: x = past prices and features, y = prices ahead
        seq_x, seq_y = seq[i:end, :], seq[end:out_end, 0]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
# function to plot the loss and accuracy for the training and testing data
def visualize_training_results(results):
    history = results.history
    plt.figure(figsize=(10,6))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'train_loss'])
    plt.title(test_comp+' - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.savefig(IMAGE_DIR+test_comp+'_loss.png', facecolor='w', edgecolor='w',
                dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
    plt.show()

# %%
# function to add hidden layers and dropout rates if necessary
def layer_maker(n_layers, n_nodes, activation, drop=None, d_rate=.5):
    """
    Creates a specified number of hidden layers for an RNN
    Optional: Adds regularization option - the dropout layer to prevent potential overfitting (if necessary)
    """
    
    # Creating the specified number of hidden layers with the specified number of nodes
    for x in range(1,n_layers+1):
        lstm_model.add(LSTM(n_nodes, activation=activation, return_sequences=True))

        # Adds a Dropout layer after every Nth hidden layer (the 'drop' variable)
        try:
            if x % drop == 0:
                lstm_model.add(Dropout(d_rate))
        except:
            pass

# %%
# function to get predictions
def validater(n_per_in, n_per_out):
    """
    Runs a 'For' loop to iterate through the length of the DF and create predicted values for every stated interval
    Returns a DF containing the predicted values for the model with the corresponding index values based on a business
    day frequency
    """
    
    # Creating an empty DF to store the predictions
    predictions = pd.DataFrame(index=lstm_data_scaled.index, columns=[lstm_data.columns[4]])
    predictions.Close.astype('float')

    for i in range(n_per_in, len(lstm_data_scaled)-n_per_in, n_per_out):
        # Creating rolling intervals to predict off of actual sequence values
        x = lstm_data_scaled[-i - n_per_in:-i]
        #print(x)

        # Predicting using rolling intervals
        yhat = lstm_model.predict(np.array(x).reshape(1, n_per_in, n_features))
        #print('preditions yhat', yhat)

        # Transforming values back to their normal prices
        yhat = close_sc.inverse_transform(yhat)[0]
        #print('inversed yhat', yhat)

        # DF to store the values and append later, frequency uses business days
        pred_df = pd.DataFrame(yhat, 
                               index=pd.date_range(start=x.index[-1], 
                                                   periods=len(yhat),
                                                   freq='B'),
                               columns=[x.columns[4]])
        #print('pred_df', pred_df)

        # Updating the predictions DF
        predictions.update(pred_df)
        #print('predictions', predictions)

        
    # add one cycle for last sequence????
    
    return predictions

# %%
def val_rmse(df1, df2):
    """
    Calculates the root mean square error between the two Dataframes
    """
    df = df1.copy()
    
    # Adding a new column with the closing prices from the second DF
    df['close2'] = df2.Close
    
    # Dropping the NaN values
    df.dropna(inplace=True)
    
    # Adding another column containing the difference between the two DFs' closing prices
    df['diff'] = df.Close - df.close2
    
    # Squaring the difference and getting the mean
    rmse = (df[['diff']]**2).mean()
    
    # Returning the sqaure root of the root mean square
    return float(np.sqrt(rmse))

# %% [markdown]
# ### Split and re-shape data

# %%
# Splitting the data into appropriate sequences
X, y = split_sequence(lstm_data_scaled.to_numpy(), n_per_in, n_per_out)
print(X.shape)
print(y.shape)
# Out:
# (5226, 60, 12)
# (5226, 1)

# %% [markdown]
# ## BASELINE Modeling and validation - LSTM (Un-tune)
#
# **NOTE - If there is no change in data and there is a saved model, there is no need to re-train the model. We can go to the "Loading saved model from disk" section to load the saved model and continue from there."**
#
# We will be building a simple LSTM model that takes the input of 60 periods step back to predict 1 period in the future. This will be an "un-tune" model as we will be performing tuning in another notebook. Each company in our portfolios will go through the "un-tune" and "tuned" models in order for us to compare which portfolio (domain knowledge vs unsupervised Kmeans) is more superior. As such, the "un-tune" models' collective portfolio performance shall serve as our baseline.
#
# Below explanation extracted from this great source and full credit to the original writer:
#
# https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21
#
#
# **Problem of normal Recurrent Neural Network?**
#
# Normal Recurrent Neural Networks suffer from short-term memory. If a sequence is long enough, they will have a hard time carrying information from earlier time steps to later ones. During back propagation, recurrent neural networks suffer from the vanishing gradient problem. Gradients are values used to update a neural networks weights. The vanishing gradient problem is when the gradient shrinks as it back propagates through time. If a gradient value becomes extremely small, it does not contribute too much learning.
#
# ![gradient](images/gradient_update_rule.png "gradient")
#
# So in recurrent neural networks, layers that get a small gradient update stops learning. Those are usually the earlier layers. So because these layers do not learn, RNN can forget what it seen in longer sequences, thus having a short-term memory.
#
# **LSTM** and **GRU** was created as the solution to short-term memory. They have internal mechanisms called gates that can regulate the flow of information.
#
# ![lstm_gru](images/lstm_gru.png "lstm_gru")
#
# These gates can learn which data in a sequence is important to keep or throw away. By doing that, it can pass relevant information down the long chain of sequences to make predictions. Almost all state of the art results based on recurrent neural networks are achieved with these two networks. LSTM and GRU can be found in speech recognition, speech synthesis, and text generation. You can even use them to generate captions for videos.
#
# While processing, data is pass from the previous hidden state to the next step of the sequence. The hidden state acts as the neural networks memory and it holds information on previous data the network has seen before.
#
# **Why tanh activation?**
#
# The tanh activation is used to help regulate the values flowing through the network. The tanh function squishes values to always be between -1 and 1.
#
# ![tanh](images/tanh.gif "tanh")
#
# When vectors are flowing through a neural network, it undergoes many transformations due to various math operations. So imagine a value that continues to be multiplied by lets say 3. You can see how some values can explode and become astronomical, causing other values to seem insignificant. A tanh function ensures that the values stay between -1 and 1, thus regulating the output of the neural network.
#
# **Why LSTM?**
#
# An LSTM has a similar control flow as a recurrent neural network. It processes data passing on information as it propagates forward. The differences are the operations within the LSTM’s cells that are used to allow the LSTM to keep or forget information. The cell state, in theory, can carry relevant information throughout the processing of the sequence. So even information from the earlier time steps can make its way to later time steps, reducing the effects of short-term memory. As the cell state goes on its journey, information is added or removed to the cell state via gates.
#
# ![lstm](images/lstm.png "lstm")
#
# >**Sigmoid**
# Gates contains sigmoid activations. A sigmoid activation is similar to the tanh activation. Instead of squishing values between -1 and 1, it squishes values between 0 and 1. That is helpful to update or forget data because any number getting multiplied by 0 is 0, causing values to disappears or be “forgotten.” Any number multiplied by 1 is the same value therefore that value stay’s the same or is “kept.” The network can learn which data is not important therefore can be forgotten or which data is important to keep.
#
# >**Forget gate**
# First, we have the forget gate. This gate decides what information should be thrown away or kept. Information from the previous hidden state and information from the current input is passed through the sigmoid function. Values come out between 0 and 1. The closer to 0 means to forget, and the closer to 1 means to keep.
#
# >**Input Gate**
# To update the cell state, we have the input gate. First, we pass the previous hidden state and current input into a sigmoid function. That decides which values will be updated by transforming the values to be between 0 and 1. 0 means not important, and 1 means important. You also pass the hidden state and current input into the tanh function to squish values between -1 and 1 to help regulate the network. Then you multiply the tanh output with the sigmoid output. The sigmoid output will decide which information is important to keep from the tanh output.
#
# >**Cell State**
# Now we should have enough information to calculate the cell state. First, the cell state gets pointwise multiplied by the forget vector. This has a possibility of dropping values in the cell state if it gets multiplied by values near 0. Then we take the output from the input gate and do a pointwise addition which updates the cell state to new values that the neural network finds relevant. That gives us our new cell state.
#
# >**Output Gate**
# Last we have the output gate. The output gate decides what the next hidden state should be. Remember that the hidden state contains information on previous inputs. The hidden state is also used for predictions. First, we pass the previous hidden state and the current input into a sigmoid function. Then we pass the newly modified cell state to the tanh function. We multiply the tanh output with the sigmoid output to decide what information the hidden state should carry. The output is the hidden state. The new cell state and the new hidden is then carried over to the next time step.
#
# **Why not GRU?**
#
# The GRU is pretty similar to an LSTM. GRU got rid of the cell state and used the hidden state to transfer information. It also only has two gates, a reset gate and update gate.
#
# >**Update Gate**
# The update gate acts similar to the forget and input gate of an LSTM. It decides what information to throw away and what new information to add.
#
# >**Reset Gate**
# The reset gate is another gate is used to decide how much past information to forget. GRU has fewer tensor operations so it is a little speedier to train then LSTM. There is no clear winner which one is better. Researchers and engineers usually try both to determine which one works better for their use case.

# %%
# instantiation
lstm_model = Sequential()

# set activation
activ = 'tanh'

# adding the input and first LSTM layer
lstm_model.add(LSTM(100, activation=activ, return_sequences=True,
                    input_shape=(n_per_in, n_features)))

# # final hidden layer w/o return_sequences
lstm_model.add(LSTM(100, activation=activ))

# output layer
lstm_model.add(Dense(n_per_out))

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 100)           45200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 125,701
# Trainable params: 125,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
lstm_model.compile(optimizer=Adam(lr=0.01), loss='mse')

# %%
# implementing early stop
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, mode='auto')
# min_delta=0 mean stop whenever the val_loss increases but patience=5 means wait 5 epochs before deciding
# mode='auto' mean depending on the monitor, it will decide to use min/max. e.g accuracy use max, loss use min

# %%
# Fitting the training data
results = lstm_model.fit(X, y, epochs=30, batch_size=64, validation_split=0.1, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 74/74 [==============================] - 1s 15ms/step - loss: 0.1282 - val_loss: 0.0013
# Epoch 2/30
# 74/74 [==============================] - 0s 6ms/step - loss: 3.5293e-04 - val_loss: 0.0012
# Epoch 3/30
# 74/74 [==============================] - 0s 6ms/step - loss: 2.4318e-04 - val_loss: 8.7575e-04
# Epoch 4/30
# 74/74 [==============================] - 0s 6ms/step - loss: 2.2107e-04 - val_loss: 6.6835e-04
# Epoch 5/30
# 74/74 [==============================] - 0s 6ms/step - loss: 1.7272e-04 - val_loss: 4.6820e-04
# Epoch 6/30
# 74/74 [==============================] - 0s 6ms/step - loss: 1.7173e-04 - val_loss: 4.5207e-04
# Epoch 7/30
# 74/74 [==============================] - 0s 6ms/step - loss: 1.4874e-04 - val_loss: 3.5127e-04
# Epoch 8/30
# 74/74 [==============================] - 0s 7ms/step - loss: 1.4471e-04 - val_loss: 6.3578e-04
# Epoch 9/30
# 74/74 [==============================] - 0s 7ms/step - loss: 1.2581e-04 - val_loss: 5.8078e-04
# Epoch 10/30
# 74/74 [==============================] - 0s 6ms/step - loss: 9.5061e-05 - val_loss: 2.3655e-04
# Epoch 11/30
# 74/74 [==============================] - 0s 6ms/step - loss: 8.7433e-05 - val_loss: 2.1617e-04
# Epoch 12/30
# 74/74 [==============================] - 0s 6ms/step - loss: 1.0890e-04 - val_loss: 2.3705e-04
# Epoch 13/30
# 74/74 [==============================] - 0s 6ms/step - loss: 8.5133e-05 - val_loss: 1.8412e-04
# Epoch 14/30
# 74/74 [==============================] - 0s 6ms/step - loss: 7.7292e-05 - val_loss: 1.8877e-04
# Epoch 15/30
# 74/74 [==============================] - 0s 6ms/step - loss: 6.3959e-05 - val_loss: 2.2398e-04
# Epoch 16/30
# 74/74 [==============================] - 0s 6ms/step - loss: 6.8521e-05 - val_loss: 1.7914e-04
# Epoch 17/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.4090e-05 - val_loss: 2.1432e-04
# Epoch 18/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.5641e-05 - val_loss: 3.4962e-04
# Epoch 19/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.7698e-05 - val_loss: 1.7383e-04
# Epoch 20/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.5950e-05 - val_loss: 4.3129e-04
# Epoch 21/30
# 74/74 [==============================] - 0s 6ms/step - loss: 6.8757e-05 - val_loss: 1.7932e-04
# Epoch 22/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.8775e-05 - val_loss: 2.4368e-04
# Epoch 23/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.9784e-05 - val_loss: 1.7726e-04
# Epoch 24/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.1587e-05 - val_loss: 1.7080e-04
# Epoch 25/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.1904e-05 - val_loss: 1.7122e-04
# Epoch 26/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.4091e-05 - val_loss: 1.8127e-04
# Epoch 27/30
# 74/74 [==============================] - 0s 6ms/step - loss: 6.8533e-05 - val_loss: 1.6105e-04
# Epoch 28/30
# 74/74 [==============================] - 0s 7ms/step - loss: 5.2242e-05 - val_loss: 1.6057e-04
# Epoch 29/30
# 74/74 [==============================] - 0s 6ms/step - loss: 5.4113e-05 - val_loss: 4.9573e-04
# Epoch 30/30
# 74/74 [==============================] - 0s 6ms/step - loss: 6.1463e-05 - val_loss: 2.6684e-04

# %%
# visulizing training results
visualize_training_results(results)

# %% [markdown]
# ### Exporting trained model to disk
#
# This step should always be executed after a new model has been train with new data in order to save the model and trained weights to disk. When we open this notebook in the future and as long as data sets have no changes. We can skip the model training section to save time and just load the previous model and weights from disk to continue with the predictions and evaluation codes. This allow us to adjust our trading strategies without have to re-run the LSTM model training.
#
# This will allow us to re-use this notebook for different companies to record and save the results to an external file for total portfolio evaluation later.

# %%
# serialize model to JSON
filepath = 'saved_models/without_keras_tuning/'+test_comp
lstm_model_json = lstm_model.to_json()
with open(filepath+'_lstm_model.json', 'w') as json_file:
    json_file.write(lstm_model_json)

# %%
# serialize weights to HDF5
lstm_model.save_weights(filepath+'_lstm_model.h5')
print('Saved model to disk')
# Out:
# Saved model to disk

# %% [markdown]
# ### Loading saved model from disk
#
# **NOTE - If we have a saved model and there are no data changes, we can run this section to load the saved model and weights without having to re-run the training epochs.**
#
# **STEPS:**
# 1. Clear notebook kernel.
# 2. Go to section "IMPORTANT VARIABLES SETTINGS", update the `test_comp` variable with the company ticker.
# 2. Run from beginning of notebook and stop just before MODELING AND VALIDATION.
# 3. Continue running from "LOADING SAVED MODEL" till the end of the notebook to generate all the the plots and result csv files.

# %%
# load json and create model
filepath = 'saved_models/without_keras_tuning/'+test_comp
json_file = open(filepath+'_lstm_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
lstm_model = model_from_json(loaded_model_json)

# %%
# load weights into new model
lstm_model.load_weights(filepath+'_lstm_model.h5')
print('Loaded model from disk')
# Out:
# Loaded model from disk

# %%
# Transforming the actual values to their original price
actual = pd.DataFrame(close_sc.inverse_transform(lstm_data_scaled[["Close"]]), 
                      index=lstm_data.index, 
                      columns=[lstm_data.columns[4]])
actual.tail()
# Out:
#                 Close
# Date
# 2020-12-29  44.280884
# 2020-12-30  44.122169
# 2020-12-31  44.389999
# 2021-01-04  43.959999
# 2021-01-05  43.980000

# %%
# Getting a DF of the predicted values to validate against
print('WARNING: This PREDICTION step takes a while to run due to looping every single period in the dataset')
predictions = validater(n_per_in, n_per_out)
# Out:
# WARNING: This PREDICTION step takes a while to run due to looping every single period in the dataset

# %%
# Printing the RMSE
rmse = val_rmse(actual, predictions)
print('RMSE:', rmse )
# Out:
# RMSE: 0.6130559469926499

# %%
# plotting the actual and predicted prices of the last test sequence
plt.figure(figsize=(15,8), facecolor='white')

# Printing and plotting those predictions
plt.plot(predictions, label='Predicted', marker='o', markersize=1)

# Printing and plotting the actual values
plt.plot(actual, label='Actual', marker='o', markersize=1)

plt.title(f'{test_comp} - Predicted vs Actual Closing Prices\nStep back {n_per_in} periods to forecasting the next {n_per_out} period(s)')
plt.ylabel('Price')
plt.legend()

# restricting x-axis to view
# left = datetime.datetime(2000,1,1)
# right = datetime.datetime(2020,12,30)
#plt.xlim(left, right)
#plt.xlim(data_start, data_end)

plt.grid()
plt.savefig(IMAGE_DIR+test_comp+'pred_vs_actual_all_seq.png', facecolor='w', edgecolor='w',
            dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
plt.show()

# %% [markdown]
# **Note:** This is the first visualization of how the LSTM model had learned the price trend from the sequences of 60 periods data. It is not expected that the predictions (blue) will match perfectly to the actual prices (orange). In this CSCO example, it certainly look like the "un-tune" LSTM model is performing quite well in predicting the trend closely to the actual trend.

# %% [markdown]
# ### Forecasting future prices
#
# Here we shall illustrate how to use the trained model to forecast future prices. Recall that since the model had been trained to predict 1 period future with 60 periods data history. In order to predict a future price, all we need to do is to feed 60 periods of past data to the model.
#
# In practical context, it means that at the end of trading for today we will have today's price data (Close, Open, High, Low) along with other data like Volume. Assuming that an automated process of scrapping daily for news, analyst recommendation, generating technical indicators, etc is put in-place. A complete day of updated data row will be available. By feeding this new row of data along with the past 59 periods to the model. We will be able to generate a prediction of tomorrow's closing price. This will then allow us to make a trade/no-trade decision, which can also be automated.
#
# It is entirely up to the user to decide how frequent to obtain fresh data as well as how often to re-train the model. An active day trader who have no constraints on computational resources may choose to update every day and re-train every day while a more passive trader or someone with computational resources constraint may choose to update once a week and re-train once a month. We shall observe the results of our experiment and make a update frequency recommendation at the end.

# %%
# since model has been train with 60-1, to get predictions of tmr close price, feed in tdy features data

# Predicting off of y because it contains the most recent dates
yhat = lstm_model.predict(np.array(lstm_data_scaled.tail(n_per_in)).reshape(1, n_per_in, n_features))

# Transforming the predicted values back to their original prices
yhat = close_sc.inverse_transform(yhat)[0]
                                  
# Creating a DF of the predicted prices
preds = pd.DataFrame(yhat, 
                     index=pd.date_range(start=lstm_data_scaled.index[-1]+datetime.timedelta(days=1), 
                                         periods=len(yhat), 
                                         freq="B"), 
                     columns=[lstm_data_scaled.columns[4]])
preds
# Out:
#                 Close
# 2021-01-06  42.884323

# %% [markdown]
# ### Visualize how 1 prediction sequence looks like
#
# Here we illustrate a little under the hood, how the LSTM model train and predict using 1 sequence consisting 60 periods of past features data to predict the next period closing price.

# %%
# Number of periods back to visualize the actual values
pers = n_per_in

# Transforming the actual values to their original price
actual = pd.DataFrame(close_sc.inverse_transform(lstm_data_scaled[["Close"]].tail(pers)),
                                           index=lstm_data_scaled.Close.tail(pers).index,
                                           columns=[lstm_data.columns[4]])
actual
# Out:
#                 Close
# Date
# 2020-10-09  39.529415
# 2020-10-12  40.035316
# 2020-10-13  39.489742
# 2020-10-14  39.569096
# 2020-10-15  39.648453
# 2020-10-16  39.836926
# 2020-10-19  38.983841
# 2020-10-20  38.884647
# 2020-10-21  38.745773
# 2020-10-22  38.507702
# 2020-10-23  38.507702
# 2020-10-26  37.366955
# 2020-10-27  36.573391
# 2020-10-28  35.422722
# 2020-10-29  35.402882
# 2020-10-30  35.611195
# 2020-11-02  35.611195
# 2020-11-03  36.384918
# 2020-11-04  36.275803
# 2020-11-05  36.930496
# 2020-11-06  37.228081
# 2020-11-09  37.892693
# 2020-11-10  38.408508
# 2020-11-11  39.013603
# 2020-11-12  38.358910
# 2020-11-13  41.066952
# 2020-11-16  42.197777
# 2020-11-17  41.543087
# 2020-11-18  40.987591
# 2020-11-19  40.838799
# 2020-11-20  40.640408
# 2020-11-23  41.305016
# 2020-11-24  42.267216
# 2020-11-25  42.158100
# 2020-11-27  42.356491
# 2020-11-30  42.673916
# 2020-12-01  43.189735
# 2020-12-02  43.536915
# 2020-12-03  43.755150
# 2020-12-04  44.022976
# 2020-12-07  43.993214
# 2020-12-08  44.013054
# 2020-12-09  44.330479
# 2020-12-10  43.963459
# 2020-12-11  43.963459
# 2020-12-14  43.884102
# 2020-12-15  44.360241
# 2020-12-16  44.360241
# 2020-12-17  44.459435
# 2020-12-18  45.074448
# 2020-12-21  44.518955
# 2020-12-22  44.330479
# 2020-12-23  44.022976
# 2020-12-24  44.181690
# 2020-12-28  44.558628
# 2020-12-29  44.280884
# 2020-12-30  44.122169
# 2020-12-31  44.389999
# 2021-01-04  43.959999
# 2021-01-05  43.980000

# %%
# Plotting predicted price
plt.figure(figsize=(15,8), facecolor='white')

plt.plot(actual, label="Past Actual Prices", color='grey', marker='o', markersize=5)
plt.plot(preds, label="Predicted Prices", color='g', ls='--', marker='o', markersize=10)

# plot the start and end of the step back periods
plt.axvline(x=actual.index[0], color='k', linestyle='--', label='Step Back Start Date ('+str(actual.index[0].date())+')')
plt.axvline(x=preds.index[0], color='k', linestyle='--', label='Pred Date ('+str(preds.index[0].date())+')')

plt.ylabel("Price")
plt.xlabel("Dates")
plt.xticks(fontsize=9)
plt.title(f'{test_comp} - Predicted vs Actual Closing Prices\nStep back {n_per_in} days to forecasting the next {n_per_out} days')
plt.legend()
plt.grid()
plt.savefig(IMAGE_DIR+test_comp+'pred_vs_actual_last_seq.png', facecolor='w', edgecolor='w',
            dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
plt.show()

# %% [markdown]
# **Note:** Based on the past 60 periods data of all the features available, the model was able to predict 1 period future closing price (green dot)

# %%
# Creating a DF of the current real prices
real = one_comp_df[(one_comp_df['Date']>=lstm_data.index[-1]) & \
                   (one_comp_df['Date']<=preds.index[-1])][['Date', 'Close']].set_index('Date')
print(real.shape[0])
real
# Out:
# 2
#                 Close
# Date
# 2021-01-05  43.980000
# 2021-01-06  44.400002

# %%
# Plotting predicted, actual price, current real price
plt.figure(figsize=(15,8), facecolor='white')
plt.plot(actual, label="Past Actual Prices", color='grey', marker='o', markersize=5)
plt.plot(preds, label="Predicted Prices", ls='--', color='g', marker='o', markersize=10)
plt.plot(real, label="Real Prices", color='k', marker='o', markersize=5)

# plot the start and end of the step back periods
plt.axvline(x=actual.index[0], color='k', linestyle='--', label='Step Back Start Date ('+str(actual.index[0].date())+')')
plt.axvline(x=preds.index[0], color='k', linestyle='--', label='Pred Date ('+str(preds.index[0].date())+')')

plt.ylabel("Price")
plt.xlabel("Dates")
plt.xticks(fontsize=9)
plt.title(f'{test_comp} - Predicted vs Actual Closing Prices\nStep back {n_per_in} days to forecasting the next {n_per_out} days')
plt.legend()
plt.grid()
plt.savefig(IMAGE_DIR+test_comp+'pred_vs_actual_vs_real_last_seq.png', facecolor='w', edgecolor='w',
            dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
plt.show()

# %% [markdown]
# **Note:** For illustration purpose, we added the real closing price of the predicted date to the plot (black dot). In this CSCO example, we can see that the predicted closing price is neither close to the real closing price nor is it predicted to be in the same direction. Real closing price was an uptrend from last closing price but the predicted closing price is a downtrend. This shows that the model did not get the direction right for this future date.

# %% [markdown]
# ### Visualize with Analyst's recommendations
#
# Here we shall overlay the analyst's recommendation data to illustrate it effects on the prediction.

# %%
# read analyst recom data
analyst_recom_df
# Out:
#           date  recom_type               source ticker  recom_type_ordinal
# 0   2015-10-23  Reiterated             Barclays    RCI                   3
# 1   2015-12-04   Initiated              Goldman    RCI                   2
# 2   2015-12-11     Upgrade        TD Securities    RCI                   5
# 3   2015-12-17   Downgrade       Morgan Stanley    RCI                   1
# 4   2016-04-19  Reiterated     RBC Capital Mkts    RCI                   3
# ..         ...         ...                  ...    ...                 ...
# 395 2021-01-14   Initiated  BMO Capital Markets   FBHS                   2
# 396 2021-01-15   Initiated        Deutsche Bank    GSK                   2
# 397 2021-01-20   Downgrade        Credit Suisse    GSK                   1
# 398 2021-01-21     Upgrade        Credit Suisse    TRP                   5
# 399 2021-01-21     Upgrade  BMO Capital Markets    TRP                   5
#
# [400 rows x 5 columns]

# %%
# sort and reset index
analyst_recom_df.sort_values(by='date', inplace=True)
analyst_recom_df.reset_index(drop=True, inplace=True)
analyst_recom_df
# Out:
#           date  recom_type               source ticker  recom_type_ordinal
# 0   2015-10-23  Reiterated             Barclays    RCI                   3
# 1   2015-12-04   Initiated              Goldman    RCI                   2
# 2   2015-12-11     Upgrade        TD Securities    RCI                   5
# 3   2015-12-17   Downgrade       Morgan Stanley    RCI                   1
# 4   2016-04-19  Reiterated     RBC Capital Mkts    RCI                   3
# ..         ...         ...                  ...    ...                 ...
# 395 2021-01-14   Initiated  BMO Capital Markets   FBHS                   2
# 396 2021-01-15   Initiated        Deutsche Bank    GSK                   2
# 397 2021-01-20   Downgrade        Credit Suisse    GSK                   1
# 398 2021-01-21     Upgrade        Credit Suisse    TRP                   5
# 399 2021-01-21     Upgrade  BMO Capital Markets    TRP                   5
#
# [400 rows x 5 columns]

# %%
# filtering the dates of only the require company
analyst_tmp = analyst_recom_df[analyst_recom_df['ticker']==test_comp]
analyst_tmp_date_list = analyst_tmp['date'].tolist()
analyst_tmp_date_list
# Out:
# [Timestamp('2019-08-15 00:00:00'),
#  Timestamp('2019-09-11 00:00:00'),
#  Timestamp('2019-10-10 00:00:00'),
#  Timestamp('2019-11-11 00:00:00'),
#  Timestamp('2019-11-13 00:00:00'),
#  Timestamp('2019-11-14 00:00:00'),
#  Timestamp('2019-12-12 00:00:00'),
#  Timestamp('2019-12-19 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-02-27 00:00:00'),
#  Timestamp('2020-04-17 00:00:00'),
#  Timestamp('2020-06-10 00:00:00'),
#  Timestamp('2020-06-16 00:00:00'),
#  Timestamp('2020-07-09 00:00:00'),
#  Timestamp('2020-07-16 00:00:00'),
#  Timestamp('2020-07-24 00:00:00'),
#  Timestamp('2020-09-18 00:00:00'),
#  Timestamp('2020-09-23 00:00:00'),
#  Timestamp('2020-10-12 00:00:00'),
#  Timestamp('2020-11-13 00:00:00')]

# %%
# filtering the date and close price matches
analyst_tmp_date_list_price = one_comp_df[one_comp_df['Date'].isin(analyst_tmp_date_list)][['Date', 'Close']]
analyst_tmp_date_list_price
# Out:
#             Date      Close
# 19761 2019-08-15  44.020245
# 19779 2019-09-11  47.618004
# 19800 2019-10-10  44.257759
# 19822 2019-11-11  46.127808
# 19824 2019-11-13  46.473042
# 19825 2019-11-14  43.068600
# 19844 2019-12-12  43.797436
# 19849 2019-12-19  45.916828
# 19861 2020-01-08  45.906601
# 19895 2020-02-27  38.680561
# 19930 2020-04-17  41.426807
# 19967 2020-06-10  46.244331
# 19971 2020-06-16  45.327633
# 19987 2020-07-09  45.900940
# 19992 2020-07-16  44.996677
# 19998 2020-07-24  45.606071
# 20037 2020-09-18  39.128830
# 20040 2020-09-23  37.625008
# 20053 2020-10-12  40.035316
# 20077 2020-11-13  41.066952

# %%
# merging the filtered list
analyst_tmp_merged = pd.merge(analyst_tmp, analyst_tmp_date_list_price, left_on='date', right_on='Date', indicator=True)

# filtering only analyst recom in the same date period 
analyst_tmp_merged = analyst_tmp_merged[(analyst_tmp_merged['date']>=actual.index.min()) & (analyst_tmp_merged['date']<=actual.index.max())]
analyst_tmp_merged
# Out:
#          date recom_type      source ticker  recom_type_ordinal       Date  \
# 18 2020-10-12  Downgrade   Citigroup   CSCO                   1 2020-10-12
# 19 2020-11-13    Upgrade  New Street   CSCO                   5 2020-11-13
#
#         Close _merge
# 18  40.035316   both
# 19  41.066952   both

# %%
# plot that incorporate analyst action and price on the date of action
plt.figure(figsize=(15,8), facecolor='white')
plt.plot(actual, label='Past Actual Prices', color='grey', marker='o', markersize=5)
plt.plot(preds, label='Predicted Prices', ls='--', color='g', marker='o', markersize=10)
plt.plot(real, label='Real Prices', color='k', marker='o', markersize=5)

# analyst recom plot
analyst_tmp_x = analyst_tmp_merged.date.tolist()
analyst_tmp_y = analyst_tmp_merged.Close.tolist()
plt.plot(analyst_tmp_x, analyst_tmp_y, label='Analyst recommendation', color='orange', ls='--', lw=2)    

# analyst recom label
analyst_tmp_labels = analyst_tmp_merged.recom_type.tolist()
analyst_tmp_marker = ['^' if x in ['Upgrade', 'Resumed'] else 'v' if x in ['Downgrade', 'Reiterated'] \
                      else 'o' for x in analyst_tmp_merged['recom_type']]
label_offset = [25 if x in ['Upgrade', 'Resumed'] else -30 if x in ['Downgrade', 'Reiterated'] \
                      else 25 for x in analyst_tmp_merged['recom_type']]
for l,m,x,y,o in zip(analyst_tmp_labels, analyst_tmp_marker, analyst_tmp_x, analyst_tmp_y, label_offset):
    color = ''.join(['red' if m=='v' else 'green' if m=='^' else 'black'])
    plt.scatter(x,y, marker=m, c=color, s=250, zorder=1)
    plt.annotate(l, # this is the text
                 (x, y), # this is the point to label
                 textcoords='offset points', # how to position the text
                 xytext=(0,o), # distance from text to points (x,y)
                 ha='center', # horizontal alignment can be left, right or center
                 bbox=dict(boxstyle="round", fc=color, alpha=0.5),
                 fontsize=12)
    
# plot the start and end of the step back periods
plt.axvline(x=actual.index[0], color='k', linestyle='--', label='Step Back Start Date ('+str(actual.index[0].date())+')')
plt.axvline(x=preds.index[0], color='k', linestyle='--', label='Pred Date ('+str(preds.index[0].date())+')')

plt.ylabel('Price')
plt.xlabel('Dates')
plt.xticks(fontsize=9)
plt.title(f'{test_comp} - Predicted vs Actual Closing Prices\nStep back {n_per_in} days to forecasting the next {n_per_out} days')
plt.legend()
plt.grid()
plt.savefig(IMAGE_DIR+test_comp+'pred_vs_actual_vs_real_last_seq_with_analyst.png', facecolor='w', edgecolor='w',
            dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
plt.show()

# %% [markdown]
# **Note:** In this sequence of data for CSCO, there are only two analyst's recommendations with one being an upgrade while the other a downgrade. As it is not possible to open the hood to figure out how the neural network process every bit of data, we will try to make an educated inference from this plot.
#
# From the downgrade recommendation, prices dropped from about 40 to 35 (range of 5) in about 10 periods of trading, so the model is likely to have learned that a downgrade has a bigger weight contribution to lower prices considering the amount dropped and the pace of drop, among other features data. On the other hand, from the upgrade recommendation, prices increased from about 41 to 45 (range of 4) but it took about 24 periods of trading to do so, so the model is likely to have learned that this upgrade call has a smaller contribution to higher prices given that it took longer to reach a similar range of change.
#
# As mentioned there are other features data to consider as well but if we were to isolate only the analyst recommendations in this sequence plot. What we have describe is a very likely inference as to why the predicted future closing price is lower than real closing price.

# %% [markdown]
# ### Visualize with News Sentiments
#
# Here we shall overlay the news articles' sentimental analysis data to illustrate it effects on the prediction.

# %%
# read news sentiment data
senti_mean_df
# Out:
#      ticker       date  compound Interpretation
# 0      ABBV 2020-11-24  0.180600       Positive
# 1      ABBV 2020-11-25  0.332600       Positive
# 2      ABBV 2020-11-27  0.127550       Positive
# 3      ABBV 2020-11-28  0.624900       Positive
# 4      ABBV 2020-11-29  0.000000        Neutral
# ...     ...        ...       ...            ...
# 1083    SAP 2021-01-15  0.236533       Positive
# 1084    SAP 2021-01-19  0.159100       Positive
# 1085    SAP 2021-01-20  0.000000        Neutral
# 1086    SAP 2021-01-21  0.273200       Positive
# 1087    SAP 2021-01-22  0.458800       Positive
#
# [1088 rows x 4 columns]

# %%
# filtering for only the required company
senti_mean_tmp = senti_mean_df[senti_mean_df['ticker']==test_comp]
print(senti_mean_tmp.shape)
senti_mean_tmp
# Out:
# (37, 4)
#     ticker       date  compound Interpretation
# 94    CSCO 2020-12-07  0.000000        Neutral
# 95    CSCO 2020-12-08  0.089700       Positive
# 96    CSCO 2020-12-09  0.000000        Neutral
# 97    CSCO 2020-12-12  0.000000        Neutral
# 98    CSCO 2020-12-13  0.636900       Positive
# 99    CSCO 2020-12-15  0.096900       Positive
# 100   CSCO 2020-12-17  0.197850       Positive
# 101   CSCO 2020-12-18  0.090925       Positive
# 102   CSCO 2020-12-19  0.624900       Positive
# 103   CSCO 2020-12-20  0.440400       Positive
# 104   CSCO 2020-12-21  0.000000        Neutral
# 105   CSCO 2020-12-22  0.302100       Positive
# 106   CSCO 2020-12-23  0.147567       Positive
# 107   CSCO 2020-12-24 -0.273200       Negative
# 108   CSCO 2020-12-25  0.000000        Neutral
# 109   CSCO 2020-12-27  0.331350       Positive
# 110   CSCO 2020-12-28  0.401900       Positive
# 111   CSCO 2020-12-29  0.251525       Positive
# 112   CSCO 2020-12-30  0.048067        Neutral
# 113   CSCO 2020-12-31  0.000000        Neutral
# 114   CSCO 2021-01-01  0.636900       Positive
# 115   CSCO 2021-01-03  0.636900       Positive
# 116   CSCO 2021-01-04  0.538650       Positive
# 117   CSCO 2021-01-05  0.000000        Neutral
# 118   CSCO 2021-01-06  0.340000       Positive
# 119   CSCO 2021-01-07  0.000000        Neutral
# 120   CSCO 2021-01-08  0.128331       Positive
# 121   CSCO 2021-01-09  0.636900       Positive
# 122   CSCO 2021-01-11 -0.219475       Negative
# 123   CSCO 2021-01-12  0.000000        Neutral
# 124   CSCO 2021-01-13  0.177900       Positive
# 125   CSCO 2021-01-14  0.130075       Positive
# 126   CSCO 2021-01-15 -0.120400       Negative
# 127   CSCO 2021-01-18 -0.718400       Negative
# 128   CSCO 2021-01-19  0.386350       Positive
# 129   CSCO 2021-01-20  0.038600        Neutral
# 130   CSCO 2021-01-21  0.340000       Positive

# %%
# plot that incorporate news sentiments
fig, (ax1, ax2) = plt.subplots(2,1, gridspec_kw={'height_ratios': [5, 1]},
                               figsize=(15,10), facecolor='white', sharex=True)

# plots on ax1
ax1.plot(actual, label='Past Actual Prices', color='grey', marker='o', markersize=5)
ax1.plot(preds, label='Predicted Prices', ls='-', color='g', marker='o', markersize=10)
ax1.plot(real, label='Real Prices', color='k', marker='o', markersize=5)

# analyst recom plot
analyst_tmp_x = analyst_tmp_merged.date.tolist()
analyst_tmp_y = analyst_tmp_merged.Close.tolist()
ax1.plot(analyst_tmp_x, analyst_tmp_y, label='Analyst recommendation', color='orange', ls='--', lw=2)    

# analyst recom label
analyst_tmp_labels = analyst_tmp_merged.recom_type.tolist()
analyst_tmp_marker = ['^' if x in ['Upgrade', 'Resumed'] else 'v' if x in ['Downgrade', 'Reiterated'] \
                      else 'o' for x in analyst_tmp_merged['recom_type']]
label_offset = [25 if x in ['Upgrade', 'Resumed'] else -30 if x in ['Downgrade', 'Reiterated'] \
                      else 25 for x in analyst_tmp_merged['recom_type']]
for l,m,x,y,o in zip(analyst_tmp_labels, analyst_tmp_marker, analyst_tmp_x, analyst_tmp_y, label_offset):
    color = ''.join(['red' if m=='v' else 'green' if m=='^' else 'black'])
    ax1.scatter(x,y, marker=m, c=color, s=250, zorder=1)
    ax1.annotate(l, # this is the text
                 (x, y), # this is the point to label
                 textcoords='offset points', # how to position the text
                 xytext=(0,o), # distance from text to points (x,y)
                 ha='center', # horizontal alignment can be left, right or center
                 bbox=dict(boxstyle="round", fc=color, alpha=0.5),
                 fontsize=12)
    
# plot the start and end of the step back periods
ax1.axvline(x=actual.index[0], color='k', linestyle='--', label='Step Back Start Date ('+str(actual.index[0].date())+')')
ax1.axvline(x=preds.index[0], color='k', linestyle='--', label='Pred Date ('+str(preds.index[0].date())+')')

ax1.set_title(f'{test_comp} - Predicted vs Actual Closing Prices\nStep back {n_per_in} days to forecasting the next {n_per_out} days')
ax1.set_ylabel('Price', fontsize=14)
ax1.legend()
ax1.grid()

# plots on ax2
# news sentiment plots
senti_mean_tmp_labels = ['^' if x=='Positive' else 'v' if x=='Negative' else 'o' \
                         for x in senti_mean_tmp['Interpretation']]

senti_mean_tmp_x = senti_mean_tmp[(senti_mean_tmp['date']>=actual.index.min()) & \
                                  (senti_mean_tmp['date']<=actual.index.max())]['date'].tolist()

senti_mean_tmp_y = senti_mean_tmp['compound']

for l,x,y in zip(senti_mean_tmp_labels, senti_mean_tmp_x, senti_mean_tmp_y):
    color = ''.join(['red' if l=='v' else 'green' if l=='^' else 'black'])
    ax2.scatter(x,y, marker=l, c=color, s=50)

# plot the start and end of the step back periods
ax2.axvline(x=actual.index[0], color='k', linestyle='--', label='Step Back Start Date ('+str(actual.index[0].date())+')')
ax2.axvline(x=preds.index[0], color='k', linestyle='--', label='Pred Date ('+str(preds.index[0].date())+')')

ax2.set_title('News sentiments')
ax2.set_xlabel('Dates', fontsize=14)
plt.xticks(fontsize=12)
ax2.grid()
ax2.set_ylim(-1,1)

plt.savefig(IMAGE_DIR+test_comp+'pred_vs_actual_vs_real_last_seq_with_analyst_and_news.png', facecolor='w', edgecolor='w',
            dpi=200, transparent=False, bbox_inches=None, pad_inches=0.1)
plt.show()

# %% [markdown]
# **Note:** In this sequence of 60 periods, we observed that there are no news articles in the earlier 2/3 of the sequence and there are much more positive (red) and neutral (black) news than negative (red) news. Intuitively, one would infer that with majority positive news, the prediction should be going on an uptrend. However, the model predicted to be a downtrend instead. This could be due to other features data coming into play as well that resulted in a downtrend prediction.
#
# This again illustrates that with neural network inner workings, it is not always possible to decipher why a certain result occurs. Much more so when we are modeling stock prices among many other features data. However, we have to also remember and appreciate that interpreting and processing these large amount of data manually is impossible without the help of machine learning.
#
# This in fact is a good point to pause the illustration because it is a clear evident that we cannot rely on interpreting just one sequence result to determine the effectiveness of the model. A total and collective evaluation of how the model perform for each company and also for the collection of companies in the portfolio should be the ultimate evaluation metric in our project context. In the real investment world, the success of an investor is also not measure based on one company he/she invested in but rather his entire portfolio performance over time.

# %% [markdown]
# ## Create a Trading Account Class
#
# We will need to create a new Trading Account Class object to store and perform trading actions arising from our trading strategy in subsequent stage. This class takes care of the initialization of account, deposit, withdraw, balances, freezing/unfreezing whenever call for while executing the trading strategy.

# %%
# create a trading account class object
class ticker_account:   
    def __init__(self, ticker, acct_start_bal):
        self.ticker = ticker
        self.share_balance = 0
        self.value_balance = acct_start_bal
        self.pos_hold_value = 0
        self.frozen = False
    
    # buying shares
    def deposit(self, date, trans_price, trade_size):
        result = []
        if not self.frozen:
            # calculate require amount
            trans_amount = trade_size*trans_price
            comm_fees = trans_amount*comm_rate  # commission and fees percentage
            # checking and imposing min fee of 25
            if comm_fees < min_fees:
                comm_fees = min_fees
            else:
                pass
            total_amt = -(trans_amount+comm_fees) # trans+amount PLUS commission and fees
            
            # check if enough money to buy
            if self.value_balance + total_amt < 0:
                print(date, 'ERROR! Insufficient money to buy shares.')
                print(f'{self.ticker} account has {round(self.value_balance,2)} remaining.', '\n')
                print('------------------------------\n')
                result = 'fail'
                return result
            
            elif self.value_balance + total_amt >= 0:                
                self.share_balance += trade_size
                self.value_balance += total_amt
                self.pos_hold_value += abs(total_amt)
                print(f'{date} Bought {trade_size} of {self.ticker} at OPEN {round(trans_price,2)} = $ {round(trans_amount,2)}.')
                print(f'- Commission and fees     = $ {round(comm_fees,2)}')
                print(f'- Total amount            = $ {round(total_amt,2)}')
                print(f'- Remaining qty           = {self.share_balance}')
                print(f'- Ramaining valued at     = $ {round(self.pos_hold_value,2)}')
                print(f'- Account current balance = $ {round(self.value_balance,2)}','\n')
                result = 'pass'
        else:
            print('Cannot buy - account is frozen!')
        return result
                      
    # selling shares
    def withdraw(self, date, trans_price, trade_size):
        result = []
        if not self.frozen:
            # check if account have zero share or try to short sell = not allow
            if self.share_balance==0:
                print(date, 'ERROR! Short selling not allow.')
                print(f'{self.ticker} account only has {round(self.share_balance,2)} remaining.', '\n')
                result = 'fail'
                return result
            
            elif self.share_balance - trade_size >= 0:
                # calculate require amount
                trans_amount = trade_size*trans_price
                comm_fees = trans_amount*comm_rate  # commission and fees percentage
                # checking and imposing min fee of 25
                if comm_fees < min_fees:
                    comm_fees = min_fees
                else:
                    pass
                total_amt = trans_amount-comm_fees # trans_amount MINUS commission and fees
                
                # check if trans_profit can cover comm
                if total_amt - self.pos_hold_value <= comm_fees:
                    print(f'Transaction value (incl. comm & fees) = $ {round(total_amt,2)}')
                    print('Transaction profit cannot cover commission so HOLD')
                    print('------------------------------\n')
                    result = 'fail'
                    return result
                else:
                    self.share_balance -= trade_size
                    self.value_balance += total_amt
                    self.pos_hold_value = 0
                    print(f'{date} Sold {trade_size} of {self.ticker} at OPEN {round(trans_price,2)} = $ {round(trans_amount,2)}.')
                    print(f'- Commission and fees  = $ {round(comm_fees,2)}')
                    print(f'- Total amount         = {round(total_amt,2)}')
                    print(f'- Remaining qty        = {self.share_balance}')
                    print(f'- Remaining valued at  = $ {round(self.pos_hold_value,2)}')
                    print(f'- Account balance      = $ {round(self.value_balance,2)}','\n')
                    result = 'pass'
            else:
                print('ERROR CHECK WITHDRAW FUNCTION!!\n')
        else:
            print('CANNOT SELL - ACCOUNT IS FROZEN!!\n')
        return result

    # check balances
    def view_balance(self):
        print(f'{self.ticker} account has {self.share_balance} shares remaining.')
        print(f'{self.ticker} account has $ {round(self.pos_hold_value,2)} shares on hand value.')
        print(f'{self.ticker} account has $ {round(self.value_balance,2)} remaining.')
        print('------------------------------\n')
        return self.value_balance

    # account freeze
    def _freeze(self):
        self.frozen = True
    
    # account unfreeze
    def _unfreeze(self):
        self.frozen = False

# %% [markdown]
# ## Create a Trading Robot
#
# Trading robot functions are created to handle the records keeping task of our trading actions. This will allow us to review and audit the trade actions to ensure it was done correctly as planned and it can also help us to fine-tune the trading strategy.

# %%
# helper function for buy action
def buy_record(test_comp, comp_account, date, trans_price, trade_size, pred_trend):
    trans_record = []
    trans_amount = trade_size*trans_price
    comm_fees = trans_amount*comm_rate  # commission and fees percentage
    
    # checking and imposing min fee of 25
    if comm_fees < min_fees:
        comm_fees = min_fees
    else:
        pass
    
    total_amt = -(trans_amount+comm_fees) # add commission and fees
    
    trans_record.append({'trans_date': date, 'ticker' : test_comp, 'qty' : trade_size,
                         'price' : trans_price, 'action' : 'buy', 'comm_fees' : comm_fees,
                         'trans_amount' : trans_amount, 'total_plus_comm_fees' : total_amt,
                         'acct_bal' : comp_account.view_balance(), 'pred_trend' : pred_trend})
    return trans_record

# %%
# helper function for sell action
def sell_record(test_comp, comp_account, date, trans_price, trade_size, pred_trend):
    trans_record = []
    trans_amount = trade_size*trans_price
    comm_fees = trans_amount*comm_rate  # commission and fees percentage
    
    # checking and imposing min fee of 25
    if comm_fees < min_fees:
        comm_fees = min_fees
    else:
        pass
    
    total_amt = trans_amount-comm_fees # minus commission and fees
    
    trans_record.append({'trans_date': date, 'ticker' : test_comp, 'qty' : trade_size,
                         'price' : trans_price, 'action' : 'sell', 'comm_fees' : comm_fees,
                         'trans_amount' : trans_amount, 'total_plus_comm_fees' : total_amt,
                         'acct_bal' : comp_account.view_balance(), 'pred_trend' : pred_trend})
    return trans_record

# %%
# helper function for hold action
def hold_record(test_comp, comp_account, date, trans_price, trade_size, pred_trend):
    trans_record = []
    trans_amount = 0
    comm_fees = 0  # commission and fees percentage 0.2% per trade
    total_amt = trans_amount+comm_fees # minus commission and fees

    trans_record.append({'trans_date': date, 'ticker' : test_comp, 'qty' : trade_size,
                         'price' : trans_price, 'action' : 'hold', 'comm_fees' : comm_fees,
                         'trans_amount' : trans_amount, 'total_plus_comm_fees' : total_amt,
                         'acct_bal' : comp_account.view_balance(), 'pred_trend' : pred_trend})
    return trans_record

# %%
# helper function for non-trading day
def non_trade_record(test_comp, date):
    trans_record = []
    trans_record.append({'trans_date': date, 'ticker' : test_comp, 'qty' : '-',
                         'price' : '-', 'action' : '-', 'comm_fees' : '-',
                         'trans_amount' : '-', 'total_plus_comm_fees' : '-',
                         'acct_bal' : '-', 'pred_trend' : '-'})
    return trans_record

# %% [markdown]
# ## Backtesting long term simple strategy
#
# **Buy low, Sell high, No short, Never pay min commission/fees**
#
# In order to make a complete and meaning assessment of the ML model, the best way is to apply the predictions and backtest them over a period to simulate a real investment. There are ready made backtesting libraries out there but we decided to build our own from scratch because only in this way can we look under the hood to evaluate and audit if our model and trading strategy actually work as intended.
#
# We shall design a simple strategy that gives absolute trust to the model's predictions and taking no risk at all based on the following rules.
#
# 1. Whenever tomorrow close price is predicted to be higher than today close price by a predicted percentage gain. We shall buy at tomorrow open price.
#
# 2. Whenever tomorrow close price is predicted to be lower than today close price. We shall sell everything on hand at tomorrow open price.
#
# 3. At all time, there will be no short selling transaction.
#
# 4. In all buy trades, we will adjust the trade size such that the commission/fees is not lower than the min fees.
#
# 5. In all sell trades, we will not enter a sell trade if the resulting predicted gain is lower than the min fees.
#
# Recall that we made these variables declaration in the "IMPORTANT VARIABLES SETTINGS" section.
# ```
# # setting account starting balance and pred_pct_gain in daily prices before making a trade
# acct_start_bal = 50000
# pred_pct_gain = 1.05
#
# # setting commission and fees (based on DBS OET US market fees)
# comm_rate = 0.0015 # 0.15% on trans_amount each time but a min. of $18 will be imposed in the buy/sell functions
# min_fees = 18
# ```
#
# We shall test the "un-tune" model and our simple strategy over a long term investment horizon of 20 yrs as well as a shorter 1 yr horizon. This will truly be a complete evaluation of our "un-tune" vs "tuned" models over different investment horizon and compare between a domain knowledge portfolio vs a unsupervised learning Kmeans portfolio.

# %% [markdown]
# ### Settings

# %%
# set and check boundaries
backtest_start = predictions.index.min()

# leaving out the date ranges where we did not make any predictions
backtest_end = predictions.tail(n_per_in).index.min() - datetime.timedelta(days=n_per_out)
print(backtest_start)
print(backtest_end)
# Out:
# 2000-01-03 00:00:00
# 2020-10-08 00:00:00

# %%
# combining predictions with actuals
backtest_data = pd.merge(lstm_data, predictions, left_on=lstm_data.index, right_on=predictions.index)
backtest_data.rename(columns={'key_0': 'date', 'Close_x': 'Close', 'Close_y': 'pred_close'}, inplace=True)

# filtering backtest_data to date ranges where we have made a prediction
backtest_data = backtest_data[(backtest_data.date>=backtest_start) & (backtest_data.date<=backtest_end)]
print(backtest_data.shape)
backtest_data.head()
# Out:
# (5226, 14)
#         date       Open       High        Low      Volume      Close  \
# 0 2000-01-03  41.107361  41.224210  38.723648  53076000.0  40.406269
# 1 2000-01-04  39.448125  40.008999  38.045941  50805600.0  38.139420
# 2 2000-01-05  37.414962  39.074214  36.363323  68524000.0  38.022575
# 3 2000-01-06  37.695389  38.092675  36.877448  48242600.0  37.391582
# 4 2000-01-07  37.157902  39.635096  37.157902  62260600.0  39.588356
#
#        SMA20      RSI14      MOM5           OBV     ATR14  recom_type_ordinal  \
# 0  38.190832  73.983820  1.074997  1.792563e+10  1.256790                 0.0
# 1  38.260941  55.907587 -1.191853  1.787482e+10  1.335614                 0.0
# 2  38.264447  55.159485 -1.659248  1.780630e+10  1.433848                 0.0
# 3  38.265615  51.176894 -2.313610  1.775806e+10  1.418233                 0.0
# 4  38.401160  61.577839 -0.467384  1.782032e+10  1.493873                 0.0
#
#    compound pred_close
# 0       0.0        NaN
# 1       0.0        NaN
# 2       0.0        NaN
# 3       0.0        NaN
# 4       0.0        NaN

# %%
# fill nan with 0 for record rows without prediction values
backtest_data['pred_close'].fillna(0, inplace=True)
backtest_data.tail()
# Out:
#            date       Open       High        Low      Volume      Close  \
# 5221 2020-10-02  37.743896  38.239874  37.664542  24493000.0  37.962128
# 5222 2020-10-05  38.170440  38.477947  37.972048  26929100.0  38.259716
# 5223 2020-10-06  38.190279  39.033440  38.091085  28430800.0  38.259716
# 5224 2020-10-07  38.666415  39.261591  38.468023  20593700.0  39.083038
# 5225 2020-10-08  39.479820  39.856764  39.340947  19031300.0  39.469902
#
#           SMA20      RSI14      MOM5           OBV     ATR14  \
# 5221  38.837444  35.906999  0.170029  2.132684e+10  0.807506
# 5222  38.744353  39.097353 -0.200748  2.135377e+10  0.786671
# 5223  38.691560  39.097353 -0.131947  2.135377e+10  0.797791
# 5224  38.673544  47.484914  0.367023  2.137436e+10  0.812369
# 5225  38.702392  50.906270  0.982037  2.139339e+10  0.809608
#
#       recom_type_ordinal  compound  pred_close
# 5221                 0.0       0.0   36.800823
# 5222                 0.0       0.0   37.180161
# 5223                 0.0       0.0   37.241634
# 5224                 0.0       0.0   38.165600
# 5225                 0.0       0.0   38.610947

# %%
# drop duplicated rows
print(backtest_data.duplicated().sum())
backtest_data.drop_duplicates(inplace=True)
backtest_data.reset_index(drop=True, inplace=True)
backtest_data.shape
# Out:
# 0
# (5226, 14)

# %%
# initialize account class
comp_account = ticker_account(test_comp, acct_start_bal)
print(f'Account starting balance $ {comp_account.value_balance}')
# Out:
# Account starting balance $ 50000

# %%
# executing the strategy
all_trans_record = []

for i in range(1, backtest_data.shape[0]):
    trans_record = []
    trade_size = 10

    if backtest_data['pred_close'][i] <= 0:
        #print(i, 'Error!! Null or negative prediction')
        #trans_record = non_trade_record(test_comp, backtest_data['date'][i])
        # function is defined but not triggering to reduce clutter as the first 60 periods have
        # no prediction values (which is correct)
        pass
    
    # tmr pred close same as tdy close price, HOLD
    elif backtest_data['pred_close'][i] == backtest_data['Close'][i-1]:
        print(i, 'tmr close = tdy close so HOLD')
        pred_trend = 'no change'
        trans_price = 0
        trade_size = 0
        trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        
    # tmr pred close higher than tdy close by a certain %, BUY
    elif (backtest_data['pred_close'][i] > backtest_data['Close'][i-1]) and\
         (backtest_data['pred_close'][i] / backtest_data['Close'][i-1]) >= pred_pct_gain:
        
        print(f'{i}, Tmr pred close {round(backtest_data.pred_close[i],2)} >({pred_pct_gain}%) Tdy close {round(backtest_data.Close[i-1],2)} so BUY')
        pred_trend = 'up'
        trans_price = backtest_data['Open'][i]
        
        # checking and adjusting trade_size to make paying min_fees worth it
        while (trade_size*trans_price*comm_rate) < min_fees:
            trade_size += 10
       
        if comp_account.deposit(backtest_data['date'][i], trans_price, trade_size)=='pass': # able to buy
            trans_record = buy_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        else:
            print(f'{i}, {backtest_data.date[i]} Insufficient money to buy shares.')
            print('------------------------------\n')
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
            
    # tmr pred close lower than tdy close, SELL
    elif backtest_data['pred_close'][i] < backtest_data['Close'][i-1]:
        print(f'{i}, Tmr pred close {round(backtest_data.pred_close[i],2)} < Tdy close {round(backtest_data.Close[i-1],2)} so SELL')
        pred_trend = 'down'
        trans_price = backtest_data['Open'][i]
        trade_size = comp_account.share_balance
        if comp_account.withdraw(backtest_data['date'][i], trans_price, trade_size)=='pass': # able to sell
            trans_record = sell_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        else:
            print(f'{i}, {backtest_data.date[i]} Short selling not allow.')
            print('------------------------------\n')
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
    else:
        print(f'{i}, {backtest_data.date[i]} NO TRADING RECOMMENDATION TODAY')
        print('------------------------------\n')
        # recording price_trend only
        if (backtest_data['pred_close'][i] > backtest_data['Close'][i-1]):
            pred_trend = 'up'
            trans_price = 0
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        elif backtest_data['pred_close'][i] < backtest_data['Close'][i-1]:
            pred_trend = 'down'
            trans_price = 0
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)       
            
    all_trans_record.append(trans_record)
# Out:
# 60, Tmr pred close 55.85 < Tdy close 58.24 so SELL
# 2000-03-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 60, 2000-03-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 61, Tmr pred close 53.47 < Tdy close 56.88 so SELL
# 2000-03-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 61, 2000-03-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 62, 2000-03-31 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 63, Tmr pred close 53.32 < Tdy close 57.82 so SELL
# 2000-04-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 63, 2000-04-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 64, Tmr pred close 52.9 < Tdy close 54.54 so SELL
# 2000-04-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 64, 2000-04-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 65, Tmr pred close 53.53 < Tdy close 54.69 so SELL
# 2000-04-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 65, 2000-04-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 66, Tmr pred close 53.03 < Tdy close 53.94 so SELL
# 2000-04-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 66, 2000-04-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 67, 2000-04-07 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 68, Tmr pred close 53.29 < Tdy close 56.04 so SELL
# 2000-04-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 68, 2000-04-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 69, Tmr pred close 51.2 < Tdy close 54.26 so SELL
# 2000-04-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 69, 2000-04-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 70, Tmr pred close 48.33 < Tdy close 52.35 so SELL
# 2000-04-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 70, 2000-04-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 71, Tmr pred close 45.6 < Tdy close 48.61 so SELL
# 2000-04-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 71, 2000-04-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 72, Tmr pred close 41.49 < Tdy close 45.71 so SELL
# 2000-04-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 72, 2000-04-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 73, Tmr pred close 48.29 >(1.05%) Tdy close 42.63 so BUY
# 2000-04-17 00:00:00 Bought 290 of CSCO at OPEN 42.58 = $ 12348.1.
# - Commission and fees     = $ 18.52
# - Total amount            = $ -12366.63
# - Remaining qty           = 290
# - Ramaining valued at     = $ 12366.63
# - Account current balance = $ 37633.37
#
# CSCO account has 290 shares remaining.
# CSCO account has $ 12366.63 shares on hand value.
# CSCO account has $ 37633.37 remaining.
# ------------------------------
#
# 74, 2000-04-18 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 290 shares remaining.
# CSCO account has $ 12366.63 shares on hand value.
# CSCO account has $ 37633.37 remaining.
# ------------------------------
#
# 75, Tmr pred close 48.75 < Tdy close 51.79 so SELL
# 2000-04-19 00:00:00 Sold 290 of CSCO at OPEN 52.16 = $ 15126.77.
# - Commission and fees  = $ 22.69
# - Total amount         = 15104.08
# - Remaining qty        = 0
# - Remaining valued at  = $ 0
# - Account balance      = $ 52737.45
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 76, Tmr pred close 48.37 < Tdy close 49.45 so SELL
# 2000-04-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 76, 2000-04-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 77, Tmr pred close 47.45 < Tdy close 48.7 so SELL
# 2000-04-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 77, 2000-04-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 78, 2000-04-25 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 79, Tmr pred close 48.08 < Tdy close 49.36 so SELL
# 2000-04-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 79, 2000-04-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 80, Tmr pred close 49.54 < Tdy close 49.92 so SELL
# 2000-04-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 80, 2000-04-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 81, Tmr pred close 50.6 < Tdy close 51.6 so SELL
# 2000-04-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 81, 2000-04-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 82, 2000-05-01 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 83, Tmr pred close 50.01 < Tdy close 53.42 so SELL
# 2000-05-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 83, 2000-05-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 84, Tmr pred close 48.32 < Tdy close 50.85 so SELL
# 2000-05-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 84, 2000-05-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 85, Tmr pred close 46.66 < Tdy close 49.4 so SELL
# 2000-05-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 85, 2000-05-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 86, 2000-05-05 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 87, Tmr pred close 45.65 < Tdy close 50.67 so SELL
# 2000-05-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 87, 2000-05-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 88, Tmr pred close 45.65 < Tdy close 46.93 so SELL
# 2000-05-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 88, 2000-05-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 89, Tmr pred close 43.31 < Tdy close 46.93 so SELL
# 2000-05-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 89, 2000-05-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 90, 2000-05-11 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 91, Tmr pred close 43.5 < Tdy close 45.06 so SELL
# 2000-05-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 91, 2000-05-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 92, Tmr pred close 43.59 < Tdy close 44.82 so SELL
# 2000-05-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 92, 2000-05-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 93, Tmr pred close 44.2 < Tdy close 44.87 so SELL
# 2000-05-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 93, 2000-05-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 94, Tmr pred close 42.87 < Tdy close 45.29 so SELL
# 2000-05-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 94, 2000-05-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 95, Tmr pred close 41.02 < Tdy close 43.37 so SELL
# 2000-05-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 95, 2000-05-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 96, Tmr pred close 39.0 < Tdy close 41.41 so SELL
# 2000-05-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 96, 2000-05-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 97, Tmr pred close 39.93 < Tdy close 39.96 so SELL
# 2000-05-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 97, 2000-05-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 98, Tmr pred close 37.68 < Tdy close 41.32 so SELL
# 2000-05-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 98, 2000-05-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 52737.45 remaining.
# ------------------------------
#
# 99, Tmr pred close 39.98 >(1.05%) Tdy close 37.8 so BUY
# 2000-05-24 00:00:00 Bought 320 of CSCO at OPEN 37.77 = $ 12084.96.
# - Commission and fees     = $ 18.13
# - Total amount            = $ -12103.09
# - Remaining qty           = 320
# - Ramaining valued at     = $ 12103.09
# - Account current balance = $ 40634.36
#
# CSCO account has 320 shares remaining.
# CSCO account has $ 12103.09 shares on hand value.
# CSCO account has $ 40634.36 remaining.
# ------------------------------
#
# 100, Tmr pred close 40.63 < Tdy close 41.22 so SELL
# 2000-05-25 00:00:00 Sold 320 of CSCO at OPEN 41.93 = $ 13416.1.
# - Commission and fees  = $ 20.12
# - Total amount         = 13395.98
# - Remaining qty        = 0
# - Remaining valued at  = $ 0
# - Account balance      = $ 54030.34
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54030.34 remaining.
# ------------------------------
#
# 101, Tmr pred close 40.33 < Tdy close 40.76 so SELL
# 2000-05-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 101, 2000-05-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54030.34 remaining.
# ------------------------------
#
# 102, Tmr pred close 43.52 >(1.05%) Tdy close 41.08 so BUY
# 2000-05-30 00:00:00 Bought 280 of CSCO at OPEN 42.99 = $ 12036.82.
# - Commission and fees     = $ 18.06
# - Total amount            = $ -12054.88
# - Remaining qty           = 280
# - Ramaining valued at     = $ 12054.88
# - Account current balance = $ 41975.46
#
# CSCO account has 280 shares remaining.
# CSCO account has $ 12054.88 shares on hand value.
# CSCO account has $ 41975.46 remaining.
# ------------------------------
#
# 103, Tmr pred close 42.75 < Tdy close 44.78 so SELL
# 2000-05-31 00:00:00 Sold 280 of CSCO at OPEN 44.08 = $ 12341.09.
# - Commission and fees  = $ 18.51
# - Total amount         = 12322.58
# - Remaining qty        = 0
# - Remaining valued at  = $ 0
# - Account balance      = $ 54298.05
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 104, 2000-06-01 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 105, 2000-06-02 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 106, Tmr pred close 46.38 < Tdy close 48.14 so SELL
# 2000-06-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 106, 2000-06-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 107, Tmr pred close 44.91 < Tdy close 47.3 so SELL
# 2000-06-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 107, 2000-06-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 108, 2000-06-07 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 109, Tmr pred close 46.94 < Tdy close 47.02 so SELL
# 2000-06-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 109, 2000-06-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 110, Tmr pred close 46.65 < Tdy close 47.63 so SELL
# 2000-06-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 110, 2000-06-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 111, Tmr pred close 45.71 < Tdy close 48.14 so SELL
# 2000-06-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 111, 2000-06-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 112, 2000-06-13 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 113, Tmr pred close 47.75 < Tdy close 48.61 so SELL
# 2000-06-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 113, 2000-06-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 114, Tmr pred close 48.14 < Tdy close 48.75 so SELL
# 2000-06-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 114, 2000-06-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 115, Tmr pred close 48.91 < Tdy close 49.73 so SELL
# 2000-06-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 115, 2000-06-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 116, Tmr pred close 49.87 < Tdy close 50.71 so SELL
# 2000-06-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 116, 2000-06-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 117, Tmr pred close 48.81 < Tdy close 51.55 so SELL
# 2000-06-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 117, 2000-06-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 118, Tmr pred close 48.67 < Tdy close 50.2 so SELL
# 2000-06-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 118, 2000-06-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 119, Tmr pred close 47.22 < Tdy close 50.43 so SELL
# 2000-06-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 119, 2000-06-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 120, Tmr pred close 45.84 < Tdy close 48.28 so SELL
# 2000-06-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 120, 2000-06-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 121, Tmr pred close 45.65 < Tdy close 46.83 so SELL
# 2000-06-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 121, 2000-06-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 122, Tmr pred close 45.75 < Tdy close 46.97 so SELL
# 2000-06-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 122, 2000-06-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 123, Tmr pred close 46.25 < Tdy close 46.55 so SELL
# 2000-06-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 123, 2000-06-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 124, Tmr pred close 44.94 < Tdy close 47.53 so SELL
# 2000-06-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 124, 2000-06-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 125, 2000-06-30 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 126, Tmr pred close 47.07 < Tdy close 47.53 so SELL
# 2000-07-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 126, 2000-07-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 127, Tmr pred close 45.57 < Tdy close 48.33 so SELL
# 2000-07-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 127, 2000-07-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 128, 2000-07-06 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 129, Tmr pred close 47.9 < Tdy close 48.42 so SELL
# 2000-07-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 129, 2000-07-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 130, Tmr pred close 46.19 < Tdy close 48.89 so SELL
# 2000-07-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 130, 2000-07-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 131, Tmr pred close 45.41 < Tdy close 47.21 so SELL
# 2000-07-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 131, 2000-07-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 132, 2000-07-12 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 133, 2000-07-13 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 134, 2000-07-14 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 135, Tmr pred close 50.33 < Tdy close 51.04 so SELL
# 2000-07-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 135, 2000-07-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 136, Tmr pred close 49.35 < Tdy close 52.07 so SELL
# 2000-07-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 136, 2000-07-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 137, Tmr pred close 48.98 < Tdy close 50.29 so SELL
# 2000-07-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 137, 2000-07-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 138, 2000-07-20 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 139, Tmr pred close 49.4 < Tdy close 51.97 so SELL
# 2000-07-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 139, 2000-07-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 140, Tmr pred close 48.16 < Tdy close 50.95 so SELL
# 2000-07-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 140, 2000-07-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 141, 2000-07-25 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 142, Tmr pred close 50.24 < Tdy close 50.95 so SELL
# 2000-07-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 142, 2000-07-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 143, Tmr pred close 49.2 < Tdy close 51.27 so SELL
# 2000-07-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 143, 2000-07-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 144, Tmr pred close 46.62 < Tdy close 50.85 so SELL
# 2000-07-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 144, 2000-07-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 145, 2000-07-31 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 146, Tmr pred close 46.47 < Tdy close 48.94 so SELL
# 2000-08-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 146, 2000-08-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 147, Tmr pred close 44.95 < Tdy close 47.25 so SELL
# 2000-08-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 147, 2000-08-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 148, 2000-08-03 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 149, 2000-08-04 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 150, Tmr pred close 48.17 < Tdy close 49.03 so SELL
# 2000-08-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 150, 2000-08-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 151, Tmr pred close 47.88 < Tdy close 49.54 so SELL
# 2000-08-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 151, 2000-08-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 152, 2000-08-09 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 153, Tmr pred close 46.33 < Tdy close 50.71 so SELL
# 2000-08-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 153, 2000-08-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 154, Tmr pred close 46.75 < Tdy close 47.39 so SELL
# 2000-08-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 154, 2000-08-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 155, Tmr pred close 47.05 < Tdy close 48.09 so SELL
# 2000-08-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 155, 2000-08-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 156, Tmr pred close 46.72 < Tdy close 48.24 so SELL
# 2000-08-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 156, 2000-08-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 157, Tmr pred close 45.97 < Tdy close 47.25 so SELL
# 2000-08-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 157, 2000-08-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 158, Tmr pred close 46.86 < Tdy close 47.16 so SELL
# 2000-08-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 158, 2000-08-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 159, Tmr pred close 46.69 < Tdy close 47.44 so SELL
# 2000-08-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 159, 2000-08-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 160, 2000-08-21 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 161, Tmr pred close 47.53 < Tdy close 48.98 so SELL
# 2000-08-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 161, 2000-08-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 162, 2000-08-23 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 163, Tmr pred close 48.49 < Tdy close 50.24 so SELL
# 2000-08-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 163, 2000-08-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 164, Tmr pred close 47.98 < Tdy close 49.73 so SELL
# 2000-08-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 164, 2000-08-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 165, Tmr pred close 48.25 < Tdy close 48.98 so SELL
# 2000-08-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 165, 2000-08-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 166, Tmr pred close 48.8 < Tdy close 49.4 so SELL
# 2000-08-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 166, 2000-08-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 167, Tmr pred close 48.39 < Tdy close 49.78 so SELL
# 2000-08-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 167, 2000-08-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 168, 2000-08-31 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 169, Tmr pred close 50.06 < Tdy close 51.32 so SELL
# 2000-09-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 169, 2000-09-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 170, Tmr pred close 48.12 < Tdy close 51.27 so SELL
# 2000-09-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 170, 2000-09-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 171, Tmr pred close 47.12 < Tdy close 49.36 so SELL
# 2000-09-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 171, 2000-09-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 172, 2000-09-07 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 173, Tmr pred close 46.69 < Tdy close 49.54 so SELL
# 2000-09-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 173, 2000-09-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 174, Tmr pred close 44.74 < Tdy close 47.77 so SELL
# 2000-09-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 174, 2000-09-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 175, Tmr pred close 43.75 < Tdy close 45.76 so SELL
# 2000-09-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 175, 2000-09-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 176, 2000-09-13 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 177, Tmr pred close 44.76 < Tdy close 45.85 so SELL
# 2000-09-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 177, 2000-09-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 178, Tmr pred close 45.74 < Tdy close 45.8 so SELL
# 2000-09-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 178, 2000-09-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 179, Tmr pred close 44.11 < Tdy close 46.93 so SELL
# 2000-09-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 179, 2000-09-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 180, 2000-09-19 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 181, Tmr pred close 46.09 < Tdy close 46.37 so SELL
# 2000-09-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 181, 2000-09-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 182, Tmr pred close 44.67 < Tdy close 47.21 so SELL
# 2000-09-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 182, 2000-09-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 183, Tmr pred close 43.64 < Tdy close 45.71 so SELL
# 2000-09-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 183, 2000-09-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 184, Tmr pred close 42.96 < Tdy close 45.1 so SELL
# 2000-09-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 184, 2000-09-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 185, Tmr pred close 41.31 < Tdy close 42.77 so SELL
# 2000-09-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 185, 2000-09-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 186, 2000-09-27 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 187, 2000-09-28 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 188, Tmr pred close 41.04 < Tdy close 44.45 so SELL
# 2000-09-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 188, 2000-09-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 189, 2000-10-02 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 190, 2000-10-03 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 191, 2000-10-04 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 192, Tmr pred close 41.9 < Tdy close 43.79 so SELL
# 2000-10-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 192, 2000-10-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 193, Tmr pred close 41.72 < Tdy close 43.05 so SELL
# 2000-10-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 193, 2000-10-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 194, Tmr pred close 40.0 < Tdy close 42.02 so SELL
# 2000-10-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 194, 2000-10-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 195, Tmr pred close 38.42 < Tdy close 40.15 so SELL
# 2000-10-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 195, 2000-10-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 196, Tmr pred close 37.45 < Tdy close 38.23 so SELL
# 2000-10-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 196, 2000-10-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 197, Tmr pred close 36.96 < Tdy close 38.28 so SELL
# 2000-10-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 197, 2000-10-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 54298.05 remaining.
# ------------------------------
#
# 198, Tmr pred close 40.33 >(1.05%) Tdy close 37.25 so BUY
# 2000-10-13 00:00:00 Bought 330 of CSCO at OPEN 36.69 = $ 12107.87.
# - Commission and fees     = $ 18.16
# - Total amount            = $ -12126.03
# - Remaining qty           = 330
# - Ramaining valued at     = $ 12126.03
# - Account current balance = $ 42172.02
#
# CSCO account has 330 shares remaining.
# CSCO account has $ 12126.03 shares on hand value.
# CSCO account has $ 42172.02 remaining.
# ------------------------------
# ...
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5184, Tmr pred close 45.02 < Tdy close 46.91 so SELL
# 2020-08-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5184, 2020-08-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5185, Tmr pred close 46.0 < Tdy close 46.38 so SELL
# 2020-08-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5185, 2020-08-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5186, Tmr pred close 40.84 < Tdy close 47.28 so SELL
# 2020-08-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5186, 2020-08-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5187, Tmr pred close 40.74 < Tdy close 41.99 so SELL
# 2020-08-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5187, 2020-08-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5188, Tmr pred close 40.61 < Tdy close 41.77 so SELL
# 2020-08-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5188, 2020-08-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5189, Tmr pred close 40.27 < Tdy close 41.37 so SELL
# 2020-08-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5189, 2020-08-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5190, Tmr pred close 39.71 < Tdy close 41.26 so SELL
# 2020-08-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5190, 2020-08-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5191, Tmr pred close 40.72 < Tdy close 41.15 so SELL
# 2020-08-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5191, 2020-08-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5192, Tmr pred close 40.43 < Tdy close 41.59 so SELL
# 2020-08-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5192, 2020-08-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5193, Tmr pred close 40.28 < Tdy close 41.53 so SELL
# 2020-08-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5193, 2020-08-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5194, Tmr pred close 40.02 < Tdy close 41.46 so SELL
# 2020-08-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5194, 2020-08-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5195, Tmr pred close 40.28 < Tdy close 41.24 so SELL
# 2020-08-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5195, 2020-08-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5196, Tmr pred close 40.28 < Tdy close 41.53 so SELL
# 2020-08-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5196, 2020-08-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5197, Tmr pred close 40.12 < Tdy close 41.57 so SELL
# 2020-08-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5197, 2020-08-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5198, Tmr pred close 40.2 < Tdy close 41.48 so SELL
# 2020-08-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5198, 2020-08-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5199, Tmr pred close 40.0 < Tdy close 41.5 so SELL
# 2020-09-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5199, 2020-09-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5200, Tmr pred close 40.56 < Tdy close 41.31 so SELL
# 2020-09-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5200, 2020-09-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5201, Tmr pred close 39.12 < Tdy close 41.69 so SELL
# 2020-09-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5201, 2020-09-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5202, Tmr pred close 38.98 < Tdy close 40.25 so SELL
# 2020-09-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5202, 2020-09-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5203, Tmr pred close 38.19 < Tdy close 40.12 so SELL
# 2020-09-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5203, 2020-09-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5204, Tmr pred close 38.32 < Tdy close 39.32 so SELL
# 2020-09-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5204, 2020-09-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5205, Tmr pred close 37.78 < Tdy close 39.44 so SELL
# 2020-09-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5205, 2020-09-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5206, Tmr pred close 38.17 < Tdy close 38.89 so SELL
# 2020-09-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5206, 2020-09-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5207, Tmr pred close 38.71 < Tdy close 39.2 so SELL
# 2020-09-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5207, 2020-09-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5208, Tmr pred close 38.91 < Tdy close 39.68 so SELL
# 2020-09-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5208, 2020-09-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5209, Tmr pred close 38.65 < Tdy close 39.91 so SELL
# 2020-09-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5209, 2020-09-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
# 5210, Tmr pred close 38.39 < Tdy close 39.73 so SELL
# 2020-09-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5210, 2020-09-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5211, Tmr pred close 38.25 < Tdy close 39.68 so SELL
# 2020-09-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5211, 2020-09-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5212, Tmr pred close 37.11 < Tdy close 39.13 so SELL
# 2020-09-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5212, 2020-09-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5213, Tmr pred close 37.45 < Tdy close 38.37 so SELL
# 2020-09-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5213, 2020-09-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5214, Tmr pred close 37.72 < Tdy close 38.65 so SELL
# 2020-09-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5214, 2020-09-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5215, Tmr pred close 36.16 < Tdy close 37.63 so SELL
# 2020-09-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5215, 2020-09-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5216, Tmr pred close 36.61 < Tdy close 37.2 so SELL
# 2020-09-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5216, 2020-09-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5217, Tmr pred close 37.5 < Tdy close 37.79 so SELL
# 2020-09-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5217, 2020-09-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5218, Tmr pred close 37.14 < Tdy close 38.46 so SELL
# 2020-09-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5218, 2020-09-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5219, Tmr pred close 37.65 < Tdy close 38.39 so SELL
# 2020-09-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5219, 2020-09-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5220, Tmr pred close 37.44 < Tdy close 38.72 so SELL
# 2020-10-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5220, 2020-10-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5221, Tmr pred close 36.8 < Tdy close 38.49 so SELL
# 2020-10-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5221, 2020-10-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5222, Tmr pred close 37.18 < Tdy close 37.96 so SELL
# 2020-10-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5222, 2020-10-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5223, Tmr pred close 37.24 < Tdy close 38.26 so SELL
# 2020-10-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5223, 2020-10-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5224, Tmr pred close 38.17 < Tdy close 38.26 so SELL
# 2020-10-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5224, 2020-10-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
#
# 5225, Tmr pred close 38.61 < Tdy close 39.08 so SELL
# 2020-10-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5225, 2020-10-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------

# %%
# put the strategy result into a df
all_trans_record_df = []
for i in range(len(all_trans_record)):
    if i==0:
        all_trans_record_df = pd.DataFrame(all_trans_record[i])
    else:
        all_trans_record_df = pd.concat([all_trans_record_df, pd.DataFrame(all_trans_record[i])])

# %%
# re-index and preview part of records
all_trans_record_df.reset_index(drop=True, inplace=True)
all_trans_record_df.head()
# Out:
#   trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 0 2000-03-29   CSCO    0  58.284147   hold        0.0           0.0
# 1 2000-03-30   CSCO    0  55.993906   hold        0.0           0.0
# 2 2000-03-31   CSCO    0   0.000000   hold        0.0           0.0
# 3 2000-04-03   CSCO    0  57.489571   hold        0.0           0.0
# 4 2000-04-04   CSCO    0  55.339556   hold        0.0           0.0
#
#    total_plus_comm_fees  acct_bal pred_trend
# 0                   0.0   50000.0       down
# 1                   0.0   50000.0       down
# 2                   0.0   50000.0         up
# 3                   0.0   50000.0       down
# 4                   0.0   50000.0       down

# %%
# print summary of strategy execution
print(f'Trade actions from {backtest_start} to {backtest_end}')
print(f'Looking back {n_per_in} days to predict {n_per_out} days future for company {test_comp}\n')
print(f'Total number of trade days     = {all_trans_record_df.shape[0]}')
print(f'Total trades conducted         = {len(all_trans_record_df[all_trans_record_df.qty!=0].index)}\n')
print(f'Account starting balance       = $ {acct_start_bal}')
print(f'Account ending balance         = $ {round(comp_account.value_balance,2)}')
print(f'Account shares balance         = {comp_account.share_balance}')
# Out:
# Trade actions from 2000-01-03 00:00:00 to 2020-10-08 00:00:00
# Looking back 60 days to predict 1 days future for company CSCO
#
# Total number of trade days     = 5166
# Total trades conducted         = 66
#
# Account starting balance       = $ 50000
# Account ending balance         = $ 90949.77
# Account shares balance         = 0

# %% [markdown]
# **Note:** Up till this point, it looks like we have doubled our initial investment of 50k in 20 yrs for CSCO. Let's perform audit in the next section to validate this result. No cheating!

# %% [markdown]
# ### Auditing transactions
#
# We shall perform an audit of some of the transactions to ensure that the backtest strategy is executed according to our plan and as a validation evidence that no cheating is involve in the codes to make this look good.
#
# The audit process involve two steps:
#
# **1. Strategy execution**
# - Export to excel to color label the cells to trace a buy and sell decisions and if the correct calculations are being applied.
#
#
# **2. Strategy effectiveness**
# - Adding "real_trend" and "right_call?" columns and populate them correctly based on actual data. Then comparing them to predicted data to determine the percentage of correct transaction decisions.

# %% [markdown]
# #### Step 1 - Strategy execution

# %%
# merge the df
audit_trans_df = pd.merge(all_trans_record_df, backtest_data, left_on='trans_date', right_on='date', how='left')
print(audit_trans_df.shape)
# Out:
# (5166, 24)

# %% [markdown]
# ![csco_audit1.png](images/csco_audit1.png "csco_audit")

# %% [markdown]
# **Note:** Let us briefly explain the key audit points.
#
# **Reference: Grey cells**
# - Complied with "No short selling" rule despite predicting a lower closing price for next day
#
# **Reference: Yellow cells**
# - End of 6/4/2000, predicted next day closing price to be higher and recommended a buy action
# - However, it failed the "min. predicted gain percentage" rule. Hence, no trade conducted (orange cells)
#
# **Reference: Green cells**
# - End of 14/4/2000, predicted next day closing price to be higher and recommended a buy action
# - Complied with "min. predicted gain percentage" rule. Hence, executed a buy trade (orange cells)
# - Buy trade was executed at next day opening price (orange cells) and quantity was adjusted to ensure commission/fees is not lower than the min fees of $18
#
# **Reference: Blue cells**
# - End of 18/4/2000, predicted next day closing price to be lower and recommended a sell action
# - Complied with "min. predicted gain percentage" rule. Hence, executed a sell trade (orange cells)
# - Sell trade was executed at next day opening price (orange cells) and quantity was sell everything on hand
#
# In summary, the entire strategy was executed according to the rules and plan that we have set. PASS!

# %% [markdown]
# #### Step 2 - Strategy effectiveness

# %%
# create new columns with default values first
audit_trans_df['right_call?'] = 'no'
audit_trans_df['real_trend'] = '-'

# %%
# filling new columns with effectiveness evaluation values
for i in audit_trans_df['Close'].index:
    if i == 0:
        pass
    elif audit_trans_df['Close'][i] > audit_trans_df['Close'][i-1]:
        audit_trans_df.loc[i:i,'real_trend']='up'
        if audit_trans_df['real_trend'][i] == audit_trans_df['pred_trend'][i]:
            audit_trans_df.loc[i:i,'right_call?'] = 'yes'
        else:
            audit_trans_df.loc[i:i,'right_call?'] = 'no'
    elif audit_trans_df['Close'][i] < audit_trans_df['Close'][i-1]:
        audit_trans_df.loc[i:i, 'real_trend']='down'
        if audit_trans_df['real_trend'][i] == audit_trans_df['pred_trend'][i]:
            audit_trans_df.loc[i:i, 'right_call?'] = 'yes'
        else:
            audit_trans_df.loc[i:i, 'right_call?'] = 'no'
    else:
        pass

# %%
# summing up the number and percentage of right calls
right_call = audit_trans_df[audit_trans_df['right_call?']=='yes'].shape[0]
right_call_pct = (right_call/audit_trans_df.shape[0])*100
wrong_call = audit_trans_df[audit_trans_df['right_call?']=='no'].shape[0]
wrong_call_pct = (wrong_call/audit_trans_df.shape[0])*100
print(f'Number of right calls \n{right_call} or {round(right_call_pct,2)}%\n')
print(f'Number of wrong calls \n{wrong_call} or {round(wrong_call_pct,2)}%')

# export records to df
filename = test_comp+'_trans_record.csv'
print(filename)
audit_trans_df.to_csv(TRANS_DIR+filename, index=False)
audit_trans_df.sample(frac=1).head()
# Out:
# Number of right calls
# 3159 or 61.15%
#
# Number of wrong calls
# 2007 or 38.85%
# CSCO_trans_record.csv
#      trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 1726 2007-02-12   CSCO    0  20.655112   hold        0.0           0.0
# 1666 2006-11-13   CSCO    0  20.004500   hold        0.0           0.0
# 4213 2016-12-27   CSCO    0  26.776159   hold        0.0           0.0
# 1181 2004-12-10   CSCO    0  14.470544   hold        0.0           0.0
# 3129 2012-09-05   CSCO    0  14.539701   hold        0.0           0.0
#
#       total_plus_comm_fees      acct_bal pred_trend       date       Open  \
# 1726                   0.0  83753.254816       down 2007-02-12  20.655112
# 1666                   0.0  83753.254816       down 2006-11-13  20.004500
# 4213                   0.0  89194.137857       down 2016-12-27  26.776159
# 1181                   0.0  83671.640295       down 2004-12-10  14.470544
# 3129                   0.0  88563.066134       down 2012-09-05  14.539701
#
#            High        Low      Volume      Close      SMA20      RSI14  \
# 1726  20.752329  20.505545  39247500.0  20.595285  20.164536  53.407566
# 1666  20.041891  19.832499  49334500.0  19.952152  18.435550  78.177583
# 4213  26.933460  26.741204  14175500.0  26.811115  26.348388  56.682399
# 1181  14.747241  14.448109  44146000.0  14.522892  14.451476  52.185878
# 3129  14.631531  14.440219  30580300.0  14.463176  14.220213  62.012406
#
#           MOM5           OBV     ATR14  recom_type_ordinal  compound  \
# 1726  0.022434  2.149345e+10  0.486211                 0.0       0.0
# 1666  1.495659  2.108679e+10  0.458978                 0.0       0.0
# 4213 -0.061174  2.034131e+10  0.346458                 0.0       0.0
# 1181 -0.007480  1.954427e+10  0.342159                 0.0       0.0
# 3129 -0.244883  2.023241e+10  0.293687                 0.0       0.0
#
#       pred_close right_call? real_trend
# 1726   20.187300         yes       down
# 1666   19.636881         yes       down
# 4213   26.351610          no         up
# 1181   14.238374          no         up
# 3129   14.281110         yes       down

# %% [markdown]
# **Note:** "right calls" refer to the situation where the predicted trend match with the actual trend and the opposite for "wrong calls". However, even a 0.00001 cent different will be treated as either a right or wrong call. Therefore, even though in this example of CSCO, the number of right calls or right calls % is high. It does not automatically mean that the model prediction accuracy is good. It also does not mean that we had made a trade for each of these occurrences.
#
# This is also the reason for implementing a "min. predicted percentage gain" rule before executing a trade, so as to mitigate the effect of wildfully acting upon every single trade call without any regard for the magnitude of value change in prices. It is of course still a good measure if the model can achieve a very high right calls percentage as the probability of making a profitable trade will be increase.

# %% [markdown]
# ### Portfolio closing value
#
# As we are backtesting till a specified end date, it may be possible that we are still holding some shares as of this end date. To fully evaluate the value performance of the portfolio, we shall check each company holding position and value the shares quantity at the closing price of the end date.

# %%
# looking at last 5 transactions
audit_trans_df.tail()
# Out:
#      trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 5161 2020-10-02   CSCO    0  37.743896   hold        0.0           0.0
# 5162 2020-10-05   CSCO    0  38.170440   hold        0.0           0.0
# 5163 2020-10-06   CSCO    0  38.190279   hold        0.0           0.0
# 5164 2020-10-07   CSCO    0  38.666415   hold        0.0           0.0
# 5165 2020-10-08   CSCO    0  39.479820   hold        0.0           0.0
#
#       total_plus_comm_fees      acct_bal pred_trend       date       Open  \
# 5161                   0.0  90949.767056       down 2020-10-02  37.743896
# 5162                   0.0  90949.767056       down 2020-10-05  38.170440
# 5163                   0.0  90949.767056       down 2020-10-06  38.190279
# 5164                   0.0  90949.767056       down 2020-10-07  38.666415
# 5165                   0.0  90949.767056       down 2020-10-08  39.479820
#
#            High        Low      Volume      Close      SMA20      RSI14  \
# 5161  38.239874  37.664542  24493000.0  37.962128  38.837444  35.906999
# 5162  38.477947  37.972048  26929100.0  38.259716  38.744353  39.097353
# 5163  39.033440  38.091085  28430800.0  38.259716  38.691560  39.097353
# 5164  39.261591  38.468023  20593700.0  39.083038  38.673544  47.484914
# 5165  39.856764  39.340947  19031300.0  39.469902  38.702392  50.906270
#
#           MOM5           OBV     ATR14  recom_type_ordinal  compound  \
# 5161  0.170029  2.132684e+10  0.807506                 0.0       0.0
# 5162 -0.200748  2.135377e+10  0.786671                 0.0       0.0
# 5163 -0.131947  2.135377e+10  0.797791                 0.0       0.0
# 5164  0.367023  2.137436e+10  0.812369                 0.0       0.0
# 5165  0.982037  2.139339e+10  0.809608                 0.0       0.0
#
#       pred_close right_call? real_trend
# 5161   36.800823         yes       down
# 5162   37.180161          no         up
# 5163   37.241634          no          -
# 5164   38.165600          no         up
# 5165   38.610947          no         up

# %%
# viewing shares and value balance
comp_account.view_balance()
# Out:
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 90949.77 remaining.
# ------------------------------
# 90949.76705597235

# %%
# get last row index and close price then multiply by shares_balance
if comp_account.share_balance == 0:
    closing_value_balance = 0
else:
    last_index = audit_trans_df.index.max()
    closing_value_balance = comp_account.share_balance * audit_trans_df.loc[last_index].Close
print(f'{test_comp} position closing value = {closing_value_balance}')
# Out:
# CSCO position closing value = 0

# %%
# Future value calculation
PV = acct_start_bal  # prevent value
r = 1.5  # assume 1.5% fixed deposit rate per annum which is very rare
n = len(pd.date_range(start=backtest_start, end=backtest_end, freq='Y')) #Number of periods in years
FV = PV*(1+r/100)**n

print(f'===== COMPARISON WITH BANKING =====')
print(f'Putting $ {PV} in bank for {r}% interest per year compounded over {n} yrs returns $ {round(FV,2)}')
# Out:
# ===== COMPARISON WITH BANKING =====
# Putting $ 50000 in bank for 1.5% interest per year compounded over 20 yrs returns $ 67342.75

# %% [markdown]
# ### Exporting trade results

# %%
# create a df to store comp results
result_list = ['Long Term Simple Strategy',                                 # strategy name
               backtest_start,                                              # start date of backtest
               backtest_end,                                                # end date of backtest
               n_per_in,                                                    # no. of look back periods
               n_per_out,                                                   # no. of periods to predict
               all_trans_record_df.shape[0],                                # no. of trade days
               n,                                                           # periods rounded up in yrs
               len(all_trans_record_df[all_trans_record_df.qty!=0].index),  # Total trades conducted
               acct_start_bal,                                              # Account starting balance
               comp_account.value_balance,                                  # Account ending balance               
               comp_account.share_balance,                                  # Account share balance
               closing_value_balance,                                       # Account close value               
               
               # Profit/Loss
               (comp_account.value_balance + closing_value_balance) - acct_start_bal,
               
               # Total Percentage return (whole period)
               (((comp_account.value_balance + closing_value_balance) - acct_start_bal) / acct_start_bal)*100,
               
               # Percentage return per yr
               ((((comp_account.value_balance + closing_value_balance) - acct_start_bal) / acct_start_bal)/n)*100,
               
               round(FV,2),                                                 # Banking returns               
               rmse,                                                        # RMSE
               right_call,                                                  # Number of right calls
               right_call_pct,                                              # Right calls %
               wrong_call,                                                  # Number of right calls
               wrong_call_pct]                                              # Wrong calls %

desc_list = ['Strategy Name',
             'Trade actions from',
             'Trade actions to',
             'Look back periods',
             'Prediction periods',
             'Total number of trade days',
             'In yrs rounded up',
             'Total trades conducted',
             'Account starting balance',
             'Account ending balance',             
             'Account share balance',
             'Account Close Value',  
             'Profit/Loss',             
             'Total Percentage return (whole period)',
             'Percentage return per yr',
             'Banking returns',
             'RMSE',
             'Number of right calls',
             'Right calls %',
             'Number of wrong calls',
             'Wrong calls %']

blank_df = pd.DataFrame(desc_list, columns=['Description'])
one_result_df = pd.DataFrame(result_list, columns=[test_comp])
one_result_df = pd.concat([blank_df, one_result_df], axis=1)

# export to csv
one_result_df.to_csv(PERF_DIR+test_comp+'_account_result.csv', index=False)
one_result_df
# Out:
#                                Description                       CSCO
# 0                            Strategy Name  Long Term Simple Strategy
# 1                       Trade actions from        2000-01-03 00:00:00
# 2                         Trade actions to        2020-10-08 00:00:00
# 3                        Look back periods                         60
# 4                       Prediction periods                          1
# 5               Total number of trade days                       5166
# 6                        In yrs rounded up                         20
# 7                   Total trades conducted                         66
# 8                 Account starting balance                      50000
# 9                   Account ending balance               90949.767056
# 10                   Account share balance                          0
# 11                     Account Close Value                          0
# 12                             Profit/Loss               40949.767056
# 13  Total Percentage return (whole period)                  81.899534
# 14                Percentage return per yr                   4.094977
# 15                         Banking returns               67342.750000
# 16                                    RMSE                   0.613056
# 17                   Number of right calls                       3159
# 18                           Right calls %                  61.149826
# 19                   Number of wrong calls                       2007
# 20                           Wrong calls %                  38.850174

# %% [markdown]
# ## Backtesting short term simple strategy
#
# Now we repeat the same strategy but only over one year period to test if the strategy works for a shorter investment term.

# %% [markdown]
# ### Settings

# %%
# set and check boundaries
backtest_start = backtest_end - datetime.timedelta(days=365)
print(backtest_start)
print(backtest_end)
# Out:
# 2019-10-09 00:00:00
# 2020-10-08 00:00:00

# %%
# combining predictions with actuals
backtest_data = pd.merge(lstm_data, predictions, left_on=lstm_data.index, right_on=predictions.index)
backtest_data.rename(columns={'key_0': 'date', 'Close_x': 'Close', 'Close_y': 'pred_close'}, inplace=True)

# filtering backtest_data to date ranges where we have made predictions within 1 yr
backtest_data = backtest_data[(backtest_data.date>=backtest_start) & (backtest_data.date<=backtest_end)]
backtest_data.reset_index(drop=True, inplace=True)
print(backtest_data.shape)
backtest_data.head()
# Out:
# (253, 14)
#         date       Open       High        Low      Volume      Close  \
# 0 2019-10-09  44.996182  45.235932  44.746844  16768600.0  44.919464
# 1 2019-10-10  44.161857  44.334477  43.682358  24698500.0  44.257759
# 2 2019-10-11  44.756438  45.360608  44.555049  25153600.0  44.650951
# 3 2019-10-14  44.641353  44.641353  44.113905  15076900.0  44.161854
# 4 2019-10-15  44.353662  44.670133  44.152273  18794400.0  44.459152
#
#        SMA20      RSI14      MOM5           OBV     ATR14  recom_type_ordinal  \
# 0  46.368989  41.512492  0.604164  2.155389e+10  1.059699                 0.0
# 1  46.205736  38.291653 -0.872688  2.152919e+10  1.072371                 1.0
# 2  46.057383  41.210525 -0.920631  2.155434e+10  1.074548                 0.0
# 3  45.887907  38.754842 -1.649483  2.153927e+10  1.036155                 0.0
# 4  45.759469  41.054160 -0.028767  2.155806e+10  0.999134                 0.0
#
#    compound pred_close
# 0       0.0  44.040867
# 1       0.0  43.318165
# 2       0.0  43.622894
# 3       0.0  42.802383
# 4       0.0  43.374035

# %%
# fill nan with 0 for record rows without prediction values
backtest_data['pred_close'].fillna(0, inplace=True)
backtest_data.tail()
# Out:
#           date       Open       High        Low      Volume      Close  \
# 248 2020-10-02  37.743896  38.239874  37.664542  24493000.0  37.962128
# 249 2020-10-05  38.170440  38.477947  37.972048  26929100.0  38.259716
# 250 2020-10-06  38.190279  39.033440  38.091085  28430800.0  38.259716
# 251 2020-10-07  38.666415  39.261591  38.468023  20593700.0  39.083038
# 252 2020-10-08  39.479820  39.856764  39.340947  19031300.0  39.469902
#
#          SMA20      RSI14      MOM5           OBV     ATR14  \
# 248  38.837444  35.906999  0.170029  2.132684e+10  0.807506
# 249  38.744353  39.097353 -0.200748  2.135377e+10  0.786671
# 250  38.691560  39.097353 -0.131947  2.135377e+10  0.797791
# 251  38.673544  47.484914  0.367023  2.137436e+10  0.812369
# 252  38.702392  50.906270  0.982037  2.139339e+10  0.809608
#
#      recom_type_ordinal  compound  pred_close
# 248                 0.0       0.0   36.800823
# 249                 0.0       0.0   37.180161
# 250                 0.0       0.0   37.241634
# 251                 0.0       0.0   38.165600
# 252                 0.0       0.0   38.610947

# %%
# drop duplicated rows
print(backtest_data.duplicated().sum())
backtest_data.drop_duplicates(inplace=True)
backtest_data.reset_index(drop=True, inplace=True)
backtest_data.shape
# Out:
# 0
# (253, 14)

# %%
# initialize account class
# making a suffix account name to differentiate the account from long-term strategy
test_comp_1yr_strategy = test_comp
comp_account = ticker_account(test_comp_1yr_strategy, acct_start_bal)

# %%
# executing the strategy
all_trans_record = []

for i in range(1, backtest_data.shape[0]):
    trans_record = []
    trade_size = 10

    if backtest_data['pred_close'][i] <= 0:
        #print(i, 'Error!! Null or negative prediction')
        #trans_record = non_trade_record(test_comp, backtest_data['date'][i])
        # function is defined but not triggering to reduce clutter as the first 60 periods have
        # no prediction values (which is correct)
        pass
    
    # tmr pred close same as tdy close price, HOLD
    elif backtest_data['pred_close'][i] == backtest_data['Close'][i-1]:
        print(i, 'tmr close = tdy close so HOLD')
        pred_trend = 'no change'
        trans_price = 0
        trade_size = 0
        trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        
    # tmr pred close higher than tdy close by a certain %, BUY
    elif (backtest_data['pred_close'][i] > backtest_data['Close'][i-1]) and\
         (backtest_data['pred_close'][i] / backtest_data['Close'][i-1]) >= pred_pct_gain:
        
        print(f'{i}, Tmr pred close {round(backtest_data.pred_close[i],2)} >({pred_pct_gain}%) Tdy close {round(backtest_data.Close[i-1],2)} so BUY')
        pred_trend = 'up'
        trans_price = backtest_data['Open'][i]
        
        # checking and adjusting trade_size to make paying min_fees worth it
        while (trade_size*trans_price*comm_rate) < min_fees:
            trade_size += 10
       
        if comp_account.deposit(backtest_data['date'][i], trans_price, trade_size)=='pass': # able to buy
            trans_record = buy_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        else:
            print(f'{i}, {backtest_data.date[i]} Insufficient money to buy shares.')
            print('------------------------------\n')
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
            
    # tmr pred close lower than tdy close, SELL
    elif backtest_data['pred_close'][i] < backtest_data['Close'][i-1]:
        print(f'{i}, Tmr pred close {round(backtest_data.pred_close[i],2)} < Tdy close {round(backtest_data.Close[i-1],2)} so SELL')
        pred_trend = 'down'
        trans_price = backtest_data['Open'][i]
        trade_size = comp_account.share_balance
        if comp_account.withdraw(backtest_data['date'][i], trans_price, trade_size)=='pass': # able to sell
            trans_record = sell_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        else:
            print(f'{i}, {backtest_data.date[i]} Short selling not allow.')
            print('------------------------------\n')
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
    else:
        print(f'{i}, {backtest_data.date[i]} NO TRADING RECOMMENDATION TODAY')
        print('------------------------------\n')
        # recording price_trend only
        if (backtest_data['pred_close'][i] > backtest_data['Close'][i-1]):
            pred_trend = 'up'
            trans_price = 0
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)
        elif backtest_data['pred_close'][i] < backtest_data['Close'][i-1]:
            pred_trend = 'down'
            trans_price = 0
            trade_size = 0
            trans_record = hold_record(test_comp, comp_account, backtest_data['date'][i], trans_price, trade_size, pred_trend)       
            
    all_trans_record.append(trans_record)
# Out:
# 1, Tmr pred close 43.32 < Tdy close 44.92 so SELL
# 2019-10-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 1, 2019-10-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 2, Tmr pred close 43.62 < Tdy close 44.26 so SELL
# 2019-10-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 2, 2019-10-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 3, Tmr pred close 42.8 < Tdy close 44.65 so SELL
# 2019-10-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 3, 2019-10-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 4, Tmr pred close 43.37 < Tdy close 44.16 so SELL
# 2019-10-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 4, 2019-10-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 5, Tmr pred close 43.6 < Tdy close 44.46 so SELL
# 2019-10-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 5, 2019-10-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 6, Tmr pred close 43.92 < Tdy close 44.87 so SELL
# 2019-10-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 6, 2019-10-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 7, Tmr pred close 43.48 < Tdy close 45.1 so SELL
# 2019-10-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 7, 2019-10-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 8, Tmr pred close 44.28 < Tdy close 44.79 so SELL
# 2019-10-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 8, 2019-10-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 9, Tmr pred close 44.36 < Tdy close 45.45 so SELL
# 2019-10-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 9, 2019-10-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 10, Tmr pred close 43.75 < Tdy close 45.6 so SELL
# 2019-10-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 10, 2019-10-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 11, Tmr pred close 43.2 < Tdy close 45.12 so SELL
# 2019-10-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 11, 2019-10-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 12, Tmr pred close 43.82 < Tdy close 44.51 so SELL
# 2019-10-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 12, 2019-10-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 13, Tmr pred close 44.04 < Tdy close 44.98 so SELL
# 2019-10-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 13, 2019-10-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 14, Tmr pred close 43.91 < Tdy close 45.24 so SELL
# 2019-10-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 14, 2019-10-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 15, Tmr pred close 44.28 < Tdy close 45.3 so SELL
# 2019-10-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 15, 2019-10-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 16, Tmr pred close 44.25 < Tdy close 45.61 so SELL
# 2019-10-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 16, 2019-10-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 17, Tmr pred close 43.59 < Tdy close 45.56 so SELL
# 2019-11-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 17, 2019-11-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 18, Tmr pred close 44.24 < Tdy close 45.1 so SELL
# 2019-11-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 18, 2019-11-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 19, Tmr pred close 44.46 < Tdy close 45.53 so SELL
# 2019-11-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 19, 2019-11-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 20, Tmr pred close 44.92 < Tdy close 45.8 so SELL
# 2019-11-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 20, 2019-11-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 21, Tmr pred close 45.09 < Tdy close 46.29 so SELL
# 2019-11-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 21, 2019-11-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 22, Tmr pred close 45.46 < Tdy close 46.43 so SELL
# 2019-11-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 22, 2019-11-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 23, Tmr pred close 44.73 < Tdy close 46.83 so SELL
# 2019-11-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 23, 2019-11-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 24, Tmr pred close 45.08 < Tdy close 46.13 so SELL
# 2019-11-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 24, 2019-11-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 25, Tmr pred close 46.15 < Tdy close 46.39 so SELL
# 2019-11-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 25, 2019-11-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 26, Tmr pred close 42.14 < Tdy close 46.47 so SELL
# 2019-11-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 26, 2019-11-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 27, Tmr pred close 41.81 < Tdy close 43.07 so SELL
# 2019-11-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 27, 2019-11-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 28, Tmr pred close 41.89 < Tdy close 43.24 so SELL
# 2019-11-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 28, 2019-11-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 29, Tmr pred close 42.18 < Tdy close 43.3 so SELL
# 2019-11-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 29, 2019-11-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 30, Tmr pred close 41.65 < Tdy close 43.61 so SELL
# 2019-11-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 30, 2019-11-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 31, Tmr pred close 41.82 < Tdy close 43.23 so SELL
# 2019-11-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 31, 2019-11-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 32, Tmr pred close 41.76 < Tdy close 43.0 so SELL
# 2019-11-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 32, 2019-11-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 33, Tmr pred close 42.38 < Tdy close 43.01 so SELL
# 2019-11-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 33, 2019-11-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 34, Tmr pred close 42.09 < Tdy close 43.59 so SELL
# 2019-11-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 34, 2019-11-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 35, Tmr pred close 41.9 < Tdy close 43.45 so SELL
# 2019-11-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 35, 2019-11-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 36, Tmr pred close 42.13 < Tdy close 43.39 so SELL
# 2019-11-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 36, 2019-11-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 37, Tmr pred close 41.61 < Tdy close 43.45 so SELL
# 2019-12-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 37, 2019-12-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 38, Tmr pred close 41.06 < Tdy close 42.87 so SELL
# 2019-12-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 38, 2019-12-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 39, Tmr pred close 40.88 < Tdy close 42.46 so SELL
# 2019-12-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 39, 2019-12-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 40, Tmr pred close 40.54 < Tdy close 42.09 so SELL
# 2019-12-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 40, 2019-12-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 41, Tmr pred close 40.9 < Tdy close 41.74 so SELL
# 2019-12-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 41, 2019-12-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 42, Tmr pred close 40.95 < Tdy close 42.04 so SELL
# 2019-12-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 42, 2019-12-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 43, Tmr pred close 41.1 < Tdy close 42.1 so SELL
# 2019-12-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 43, 2019-12-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 44, Tmr pred close 41.27 < Tdy close 42.29 so SELL
# 2019-12-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 44, 2019-12-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 45, 2019-12-12 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 46, Tmr pred close 42.24 < Tdy close 43.8 so SELL
# 2019-12-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 46, 2019-12-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 47, Tmr pred close 42.92 < Tdy close 43.44 so SELL
# 2019-12-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 47, 2019-12-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 48, Tmr pred close 43.15 < Tdy close 44.09 so SELL
# 2019-12-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 48, 2019-12-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 49, Tmr pred close 43.37 < Tdy close 44.54 so SELL
# 2019-12-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 49, 2019-12-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 50, 2019-12-19 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 51, Tmr pred close 44.2 < Tdy close 45.92 so SELL
# 2019-12-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 51, 2019-12-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 52, Tmr pred close 44.49 < Tdy close 45.5 so SELL
# 2019-12-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 52, 2019-12-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 53, Tmr pred close 44.28 < Tdy close 46.13 so SELL
# 2019-12-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 53, 2019-12-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 54, Tmr pred close 44.57 < Tdy close 45.82 so SELL
# 2019-12-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 54, 2019-12-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 55, Tmr pred close 44.42 < Tdy close 45.89 so SELL
# 2019-12-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 55, 2019-12-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 56, Tmr pred close 44.33 < Tdy close 45.81 so SELL
# 2019-12-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 56, 2019-12-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 57, Tmr pred close 44.65 < Tdy close 45.64 so SELL
# 2019-12-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 57, 2019-12-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 58, Tmr pred close 45.48 < Tdy close 45.99 so SELL
# 2020-01-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 58, 2020-01-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 59, Tmr pred close 44.32 < Tdy close 46.78 so SELL
# 2020-01-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 59, 2020-01-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 60, Tmr pred close 44.68 < Tdy close 46.01 so SELL
# 2020-01-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 60, 2020-01-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 61, Tmr pred close 44.4 < Tdy close 46.18 so SELL
# 2020-01-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 61, 2020-01-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 62, Tmr pred close 44.79 < Tdy close 45.88 so SELL
# 2020-01-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 62, 2020-01-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 63, Tmr pred close 44.25 < Tdy close 45.91 so SELL
# 2020-01-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 63, 2020-01-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 64, Tmr pred close 44.17 < Tdy close 45.71 so SELL
# 2020-01-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 64, 2020-01-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 65, Tmr pred close 45.11 < Tdy close 45.53 so SELL
# 2020-01-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 65, 2020-01-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 66, Tmr pred close 44.74 < Tdy close 46.34 so SELL
# 2020-01-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 66, 2020-01-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 67, Tmr pred close 45.05 < Tdy close 46.17 so SELL
# 2020-01-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 67, 2020-01-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 68, Tmr pred close 46.07 < Tdy close 46.38 so SELL
# 2020-01-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 68, 2020-01-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 69, Tmr pred close 46.03 < Tdy close 47.38 so SELL
# 2020-01-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 69, 2020-01-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 70, Tmr pred close 45.54 < Tdy close 47.36 so SELL
# 2020-01-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 70, 2020-01-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 71, Tmr pred close 46.12 < Tdy close 47.14 so SELL
# 2020-01-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 71, 2020-01-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 72, Tmr pred close 45.96 < Tdy close 47.4 so SELL
# 2020-01-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 72, 2020-01-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 73, Tmr pred close 45.8 < Tdy close 47.34 so SELL
# 2020-01-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 73, 2020-01-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 74, Tmr pred close 44.02 < Tdy close 47.19 so SELL
# 2020-01-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 74, 2020-01-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 75, Tmr pred close 44.92 < Tdy close 45.86 so SELL
# 2020-01-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 75, 2020-01-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 76, Tmr pred close 44.2 < Tdy close 46.15 so SELL
# 2020-01-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 76, 2020-01-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 77, Tmr pred close 44.35 < Tdy close 45.45 so SELL
# 2020-01-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 77, 2020-01-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 78, Tmr pred close 43.13 < Tdy close 45.64 so SELL
# 2020-01-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 78, 2020-01-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 79, Tmr pred close 44.06 < Tdy close 44.41 so SELL
# 2020-02-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 79, 2020-02-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 80, 2020-02-04 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 81, Tmr pred close 45.74 < Tdy close 46.0 so SELL
# 2020-02-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 81, 2020-02-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 82, Tmr pred close 45.61 < Tdy close 46.81 so SELL
# 2020-02-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 82, 2020-02-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 83, Tmr pred close 45.11 < Tdy close 47.04 so SELL
# 2020-02-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 83, 2020-02-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 84, Tmr pred close 45.95 < Tdy close 46.34 so SELL
# 2020-02-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 84, 2020-02-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 85, Tmr pred close 46.21 < Tdy close 47.21 so SELL
# 2020-02-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 85, 2020-02-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 86, Tmr pred close 46.81 < Tdy close 47.46 so SELL
# 2020-02-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 86, 2020-02-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 87, Tmr pred close 43.91 < Tdy close 48.23 so SELL
# 2020-02-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 87, 2020-02-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 88, Tmr pred close 44.22 < Tdy close 45.71 so SELL
# 2020-02-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 88, 2020-02-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 89, Tmr pred close 43.88 < Tdy close 45.38 so SELL
# 2020-02-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 89, 2020-02-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 90, Tmr pred close 43.66 < Tdy close 45.01 so SELL
# 2020-02-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 90, 2020-02-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 91, Tmr pred close 43.81 < Tdy close 44.72 so SELL
# 2020-02-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 91, 2020-02-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 92, Tmr pred close 43.65 < Tdy close 45.26 so SELL
# 2020-02-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 92, 2020-02-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
# 93, Tmr pred close 41.74 < Tdy close 44.73 so SELL
# 2020-02-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 93, 2020-02-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 94, Tmr pred close 40.77 < Tdy close 42.51 so SELL
# 2020-02-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 94, 2020-02-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 95, Tmr pred close 40.14 < Tdy close 41.29 so SELL
# 2020-02-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 95, 2020-02-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 96, Tmr pred close 39.62 < Tdy close 40.73 so SELL
# 2020-02-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 96, 2020-02-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 97, Tmr pred close 37.56 < Tdy close 38.68 so SELL
# 2020-02-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 97, 2020-02-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 98, Tmr pred close 38.47 < Tdy close 38.57 so SELL
# 2020-03-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 98, 2020-03-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 99, Tmr pred close 38.02 < Tdy close 39.77 so SELL
# 2020-03-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 99, 2020-03-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 100, 2020-03-04 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 101, Tmr pred close 37.88 < Tdy close 39.98 so SELL
# 2020-03-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 101, 2020-03-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 102, Tmr pred close 37.61 < Tdy close 38.23 so SELL
# 2020-03-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 102, 2020-03-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 103, Tmr pred close 36.14 < Tdy close 38.33 so SELL
# 2020-03-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 103, 2020-03-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 104, 2020-03-10 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 105, Tmr pred close 35.9 < Tdy close 38.72 so SELL
# 2020-03-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 105, 2020-03-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 106, Tmr pred close 33.27 < Tdy close 35.79 so SELL
# 2020-03-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 106, 2020-03-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 50000 remaining.
# ------------------------------
#
# 107, Tmr pred close 35.8 >(1.05%) Tdy close 32.07 so BUY
# 2020-03-13 00:00:00 Bought 360 of CSCO at OPEN 33.99 = $ 12234.8.
# - Commission and fees     = $ 18.35
# - Total amount            = $ -12253.16
# - Remaining qty           = 360
# - Ramaining valued at     = $ 12253.16
# - Account current balance = $ 37746.84
#
# CSCO account has 360 shares remaining.
# CSCO account has $ 12253.16 shares on hand value.
# CSCO account has $ 37746.84 remaining.
# ------------------------------
#
# 108, Tmr pred close 33.66 < Tdy close 36.36 so SELL
# Transaction value (incl. comm & fees) = $ 11538.64
# Transaction profit cannot cover commission so HOLD
# ------------------------------
#
# 108, 2020-03-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 360 shares remaining.
# CSCO account has $ 12253.16 shares on hand value.
# CSCO account has $ 37746.84 remaining.
# ------------------------------
#
# 109, 2020-03-17 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 360 shares remaining.
# CSCO account has $ 12253.16 shares on hand value.
# CSCO account has $ 37746.84 remaining.
# ------------------------------
#
# 110, 2020-03-18 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 360 shares remaining.
# CSCO account has $ 12253.16 shares on hand value.
# CSCO account has $ 37746.84 remaining.
# ------------------------------
#
# 111, 2020-03-19 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 360 shares remaining.
# CSCO account has $ 12253.16 shares on hand value.
# CSCO account has $ 37746.84 remaining.
# ------------------------------
#
# 112, Tmr pred close 34.5 < Tdy close 36.43 so SELL
# 2020-03-20 00:00:00 Sold 360 of CSCO at OPEN 36.97 = $ 13309.44.
# - Commission and fees  = $ 19.96
# - Total amount         = 13289.47
# - Remaining qty        = 0
# - Remaining valued at  = $ 0
# - Account balance      = $ 51036.32
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51036.32 remaining.
# ------------------------------
#
# 113, Tmr pred close 33.97 < Tdy close 34.39 so SELL
# 2020-03-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 113, 2020-03-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51036.32 remaining.
# ------------------------------
#
# 114, Tmr pred close 36.4 >(1.05%) Tdy close 33.43 so BUY
# 2020-03-24 00:00:00 Bought 350 of CSCO at OPEN 35.17 = $ 12310.83.
# - Commission and fees     = $ 18.47
# - Total amount            = $ -12329.3
# - Remaining qty           = 350
# - Ramaining valued at     = $ 12329.3
# - Account current balance = $ 38707.02
#
# CSCO account has 350 shares remaining.
# CSCO account has $ 12329.3 shares on hand value.
# CSCO account has $ 38707.02 remaining.
# ------------------------------
#
# 115, Tmr pred close 35.93 < Tdy close 37.29 so SELL
# 2020-03-25 00:00:00 Sold 350 of CSCO at OPEN 37.34 = $ 13068.21.
# - Commission and fees  = $ 19.6
# - Total amount         = 13048.61
# - Remaining qty        = 0
# - Remaining valued at  = $ 0
# - Account balance      = $ 51755.63
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 116, 2020-03-26 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 117, Tmr pred close 37.08 < Tdy close 39.2 so SELL
# 2020-03-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 117, 2020-03-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 118, 2020-03-30 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 119, Tmr pred close 37.25 < Tdy close 38.95 so SELL
# 2020-03-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 119, 2020-03-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 120, Tmr pred close 36.56 < Tdy close 37.98 so SELL
# 2020-04-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 120, 2020-04-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 121, 2020-04-02 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 122, Tmr pred close 37.42 < Tdy close 38.81 so SELL
# 2020-04-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 122, 2020-04-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 123, 2020-04-06 00:00:00 NO TRADING RECOMMENDATION TODAY
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 124, Tmr pred close 38.83 < Tdy close 40.4 so SELL
# 2020-04-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 124, 2020-04-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 125, Tmr pred close 39.53 < Tdy close 39.63 so SELL
# 2020-04-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 125, 2020-04-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 126, Tmr pred close 39.07 < Tdy close 40.71 so SELL
# 2020-04-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 126, 2020-04-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 127, Tmr pred close 39.09 < Tdy close 40.18 so SELL
# 2020-04-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 127, 2020-04-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 128, Tmr pred close 40.06 < Tdy close 40.2 so SELL
# 2020-04-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 128, 2020-04-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 129, Tmr pred close 39.35 < Tdy close 41.72 so SELL
# 2020-04-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 129, 2020-04-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 130, Tmr pred close 39.2 < Tdy close 40.49 so SELL
# 2020-04-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 130, 2020-04-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 131, Tmr pred close 40.41 < Tdy close 40.47 so SELL
# 2020-04-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 131, 2020-04-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 132, Tmr pred close 40.14 < Tdy close 41.43 so SELL
# 2020-04-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 132, 2020-04-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 133, Tmr pred close 38.43 < Tdy close 41.49 so SELL
# 2020-04-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 133, 2020-04-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# ...
# CSCO account only has 0 remaining.
#
# 210, 2020-08-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 211, Tmr pred close 45.02 < Tdy close 46.91 so SELL
# 2020-08-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 211, 2020-08-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 212, Tmr pred close 46.0 < Tdy close 46.38 so SELL
# 2020-08-12 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 212, 2020-08-12 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 213, Tmr pred close 40.84 < Tdy close 47.28 so SELL
# 2020-08-13 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 213, 2020-08-13 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 214, Tmr pred close 40.74 < Tdy close 41.99 so SELL
# 2020-08-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 214, 2020-08-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 215, Tmr pred close 40.61 < Tdy close 41.77 so SELL
# 2020-08-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 215, 2020-08-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 216, Tmr pred close 40.27 < Tdy close 41.37 so SELL
# 2020-08-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 216, 2020-08-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 217, Tmr pred close 39.71 < Tdy close 41.26 so SELL
# 2020-08-19 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 217, 2020-08-19 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 218, Tmr pred close 40.72 < Tdy close 41.15 so SELL
# 2020-08-20 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 218, 2020-08-20 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 219, Tmr pred close 40.43 < Tdy close 41.59 so SELL
# 2020-08-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 219, 2020-08-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 220, Tmr pred close 40.28 < Tdy close 41.53 so SELL
# 2020-08-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 220, 2020-08-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 221, Tmr pred close 40.02 < Tdy close 41.46 so SELL
# 2020-08-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 221, 2020-08-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 222, Tmr pred close 40.28 < Tdy close 41.24 so SELL
# 2020-08-26 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 222, 2020-08-26 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 223, Tmr pred close 40.28 < Tdy close 41.53 so SELL
# 2020-08-27 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 223, 2020-08-27 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 224, Tmr pred close 40.12 < Tdy close 41.57 so SELL
# 2020-08-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 224, 2020-08-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 225, Tmr pred close 40.2 < Tdy close 41.48 so SELL
# 2020-08-31 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 225, 2020-08-31 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 226, Tmr pred close 40.0 < Tdy close 41.5 so SELL
# 2020-09-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 226, 2020-09-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 227, Tmr pred close 40.56 < Tdy close 41.31 so SELL
# 2020-09-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 227, 2020-09-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 228, Tmr pred close 39.12 < Tdy close 41.69 so SELL
# 2020-09-03 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 228, 2020-09-03 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 229, Tmr pred close 38.98 < Tdy close 40.25 so SELL
# 2020-09-04 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 229, 2020-09-04 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 230, Tmr pred close 38.19 < Tdy close 40.12 so SELL
# 2020-09-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 230, 2020-09-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 231, Tmr pred close 38.32 < Tdy close 39.32 so SELL
# 2020-09-09 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 231, 2020-09-09 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 232, Tmr pred close 37.78 < Tdy close 39.44 so SELL
# 2020-09-10 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 232, 2020-09-10 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 233, Tmr pred close 38.17 < Tdy close 38.89 so SELL
# 2020-09-11 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 233, 2020-09-11 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 234, Tmr pred close 38.71 < Tdy close 39.2 so SELL
# 2020-09-14 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 234, 2020-09-14 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 235, Tmr pred close 38.91 < Tdy close 39.68 so SELL
# 2020-09-15 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 235, 2020-09-15 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 236, Tmr pred close 38.65 < Tdy close 39.91 so SELL
# 2020-09-16 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 236, 2020-09-16 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 237, Tmr pred close 38.39 < Tdy close 39.73 so SELL
# 2020-09-17 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 237, 2020-09-17 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 238, Tmr pred close 38.25 < Tdy close 39.68 so SELL
# 2020-09-18 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 238, 2020-09-18 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 239, Tmr pred close 37.11 < Tdy close 39.13 so SELL
# 2020-09-21 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 239, 2020-09-21 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 240, Tmr pred close 37.45 < Tdy close 38.37 so SELL
# 2020-09-22 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 240, 2020-09-22 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 241, Tmr pred close 37.72 < Tdy close 38.65 so SELL
# 2020-09-23 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 241, 2020-09-23 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 242, Tmr pred close 36.16 < Tdy close 37.63 so SELL
# 2020-09-24 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 242, 2020-09-24 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 243, Tmr pred close 36.61 < Tdy close 37.2 so SELL
# 2020-09-25 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 243, 2020-09-25 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 244, Tmr pred close 37.5 < Tdy close 37.79 so SELL
# 2020-09-28 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 244, 2020-09-28 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 245, Tmr pred close 37.14 < Tdy close 38.46 so SELL
# 2020-09-29 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 245, 2020-09-29 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 246, Tmr pred close 37.65 < Tdy close 38.39 so SELL
# 2020-09-30 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 246, 2020-09-30 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 247, Tmr pred close 37.44 < Tdy close 38.72 so SELL
# 2020-10-01 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 247, 2020-10-01 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 248, Tmr pred close 36.8 < Tdy close 38.49 so SELL
# 2020-10-02 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 248, 2020-10-02 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 249, Tmr pred close 37.18 < Tdy close 37.96 so SELL
# 2020-10-05 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 249, 2020-10-05 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 250, Tmr pred close 37.24 < Tdy close 38.26 so SELL
# 2020-10-06 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 250, 2020-10-06 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 251, Tmr pred close 38.17 < Tdy close 38.26 so SELL
# 2020-10-07 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 251, 2020-10-07 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
#
# 252, Tmr pred close 38.61 < Tdy close 39.08 so SELL
# 2020-10-08 00:00:00 ERROR! Short selling not allow.
# CSCO account only has 0 remaining.
#
# 252, 2020-10-08 00:00:00 Short selling not allow.
# ------------------------------
#
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------

# %%
# put the strategy result into a df
all_trans_record_df = []
for i in range(len(all_trans_record)):
    if i==0:
        all_trans_record_df = pd.DataFrame(all_trans_record[i])
    else:
        all_trans_record_df = pd.concat([all_trans_record_df, pd.DataFrame(all_trans_record[i])])

# %%
# re-index and preview part of records
all_trans_record_df.reset_index(drop=True, inplace=True)
all_trans_record_df.head()
# Out:
#   trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 0 2019-10-10   CSCO    0  44.161857   hold        0.0           0.0
# 1 2019-10-11   CSCO    0  44.756438   hold        0.0           0.0
# 2 2019-10-14   CSCO    0  44.641353   hold        0.0           0.0
# 3 2019-10-15   CSCO    0  44.353662   hold        0.0           0.0
# 4 2019-10-16   CSCO    0  44.459152   hold        0.0           0.0
#
#    total_plus_comm_fees  acct_bal pred_trend
# 0                   0.0   50000.0       down
# 1                   0.0   50000.0       down
# 2                   0.0   50000.0       down
# 3                   0.0   50000.0       down
# 4                   0.0   50000.0       down

# %%
# print summary of strategy execution
print(f'Trade actions from {backtest_start} to {backtest_end}')
print(f'Looking back {n_per_in} days to predict {n_per_out} days future for company {test_comp}\n')
print(f'Total number of trade days     = {all_trans_record_df.shape[0]}')
print(f'Total trades conducted         = {len(all_trans_record_df[all_trans_record_df.qty!=0].index)}\n')
print(f'Account starting balance       = $ {acct_start_bal}')
print(f'Account ending balance         = $ {round(comp_account.value_balance,2)}')
print(f'Account shares balance         = {comp_account.share_balance}')
# Out:
# Trade actions from 2019-10-09 00:00:00 to 2020-10-08 00:00:00
# Looking back 60 days to predict 1 days future for company CSCO
#
# Total number of trade days     = 252
# Total trades conducted         = 4
#
# Account starting balance       = $ 50000
# Account ending balance         = $ 51755.63
# Account shares balance         = 0

# %% [markdown]
# ### Auditing transactions
#
# Note that since the audit had proved that the strategy was executed correctly, we will only be executing the codes below to obtain the CSV files output. We will not be repeating the explanation steps again.

# %% [markdown]
# #### Step 1 - Strategy execution

# %%
# export records to df
filename = test_comp+'_1yr_strategy_trans_record.csv'
print(filename)
audit_trans_df = pd.merge(all_trans_record_df, backtest_data, left_on='trans_date', right_on='date')
# Out:
# CSCO_1yr_strategy_trans_record.csv

# %% [markdown]
# #### Step 2 - Strategy effectiveness

# %%
# create new columns with default values first
audit_trans_df['right_call?'] = 'no'
audit_trans_df['real_trend'] = '-'

# %%
# filling new columns with effectiveness evaluation values
for i in audit_trans_df['Close'].index:
    if i == 0:
        pass
    elif audit_trans_df['Close'][i] > audit_trans_df['Close'][i-1]:
        audit_trans_df.loc[i:i,'real_trend']='up'
        if audit_trans_df['real_trend'][i] == audit_trans_df['pred_trend'][i]:
            audit_trans_df.loc[i:i,'right_call?'] = 'yes'
        else:
            audit_trans_df.loc[i:i,'right_call?'] = 'no'
    elif audit_trans_df['Close'][i] < audit_trans_df['Close'][i-1]:
        audit_trans_df.loc[i:i, 'real_trend']='down'
        if audit_trans_df['real_trend'][i] == audit_trans_df['pred_trend'][i]:
            audit_trans_df.loc[i:i, 'right_call?'] = 'yes'
        else:
            audit_trans_df.loc[i:i, 'right_call?'] = 'no'
    else:
        pass

# %%
# summing up the number and percentage of right calls
right_call = audit_trans_df[audit_trans_df['right_call?']=='yes'].shape[0]
right_call_pct = (right_call/audit_trans_df.shape[0])*100
wrong_call = audit_trans_df[audit_trans_df['right_call?']=='no'].shape[0]
wrong_call_pct = (wrong_call/audit_trans_df.shape[0])*100
print(f'Number of right calls \n{right_call} or {round(right_call_pct,2)}%\n')
print(f'Number of wrong calls \n{wrong_call} or {round(wrong_call_pct,2)}%')
audit_trans_df.to_csv(TRANS_DIR+filename, index=False)
audit_trans_df.sample(frac=1).head()
# Out:
# Number of right calls
# 142 or 56.35%
#
# Number of wrong calls
# 110 or 43.65%
#     trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 81  2020-02-06   CSCO    0  47.036880   hold        0.0           0.0
# 50  2019-12-20   CSCO    0  46.271657   hold        0.0           0.0
# 0   2019-10-10   CSCO    0  44.161857   hold        0.0           0.0
# 126 2020-04-13   CSCO    0  40.022510   hold        0.0           0.0
# 117 2020-03-30   CSCO    0   0.000000   hold        0.0           0.0
#
#      total_plus_comm_fees      acct_bal pred_trend       date       Open  \
# 81                    0.0  50000.000000       down 2020-02-06  47.036880
# 50                    0.0  50000.000000       down 2019-12-20  46.271657
# 0                     0.0  50000.000000       down 2019-10-10  44.161857
# 126                   0.0  51755.629199       down 2020-04-13  40.022510
# 117                   0.0  51755.629199         up 2020-03-30  38.110597
#
#           High        Low      Volume      Close      SMA20      RSI14  \
# 81   47.162468  46.582840   9814800.0  47.036880  46.312341  58.051765
# 50   46.386736  45.475687  52575300.0  45.504459  43.348148  62.969314
# 0    44.334477  43.682358  24698500.0  44.257759  46.205736  38.291653
# 126  40.432095  39.525152  19592000.0  40.198048  37.466384  53.973171
# 117  39.115288  37.637231  27120300.0  38.951057  36.557187  51.653394
#
#          MOM5           OBV     ATR14  recom_type_ordinal  compound  \
# 81   1.400772  2.172465e+10  0.836589                 0.0       0.0
# 50   2.061852  2.170625e+10  0.783909                 0.0       0.0
# 0   -0.872688  2.152919e+10  1.072371                 1.0       0.0
# 126  2.106453  2.141791e+10  2.114660                 0.0       0.0
# 117  5.525799  2.144787e+10  2.550860                 0.0       0.0
#
#      pred_close right_call? real_trend
# 81    45.609623          no         up
# 50    44.199806         yes       down
# 0     43.318165          no          -
# 126   39.089077          no         up
# 117   38.373203         yes         up

# %% [markdown]
# ### Portfolio closing value

# %%
# looking at last 5 transactions
audit_trans_df.tail()
# Out:
#     trans_date ticker  qty      price action  comm_fees  trans_amount  \
# 247 2020-10-02   CSCO    0  37.743896   hold        0.0           0.0
# 248 2020-10-05   CSCO    0  38.170440   hold        0.0           0.0
# 249 2020-10-06   CSCO    0  38.190279   hold        0.0           0.0
# 250 2020-10-07   CSCO    0  38.666415   hold        0.0           0.0
# 251 2020-10-08   CSCO    0  39.479820   hold        0.0           0.0
#
#      total_plus_comm_fees      acct_bal pred_trend       date       Open  \
# 247                   0.0  51755.629199       down 2020-10-02  37.743896
# 248                   0.0  51755.629199       down 2020-10-05  38.170440
# 249                   0.0  51755.629199       down 2020-10-06  38.190279
# 250                   0.0  51755.629199       down 2020-10-07  38.666415
# 251                   0.0  51755.629199       down 2020-10-08  39.479820
#
#           High        Low      Volume      Close      SMA20      RSI14  \
# 247  38.239874  37.664542  24493000.0  37.962128  38.837444  35.906999
# 248  38.477947  37.972048  26929100.0  38.259716  38.744353  39.097353
# 249  39.033440  38.091085  28430800.0  38.259716  38.691560  39.097353
# 250  39.261591  38.468023  20593700.0  39.083038  38.673544  47.484914
# 251  39.856764  39.340947  19031300.0  39.469902  38.702392  50.906270
#
#          MOM5           OBV     ATR14  recom_type_ordinal  compound  \
# 247  0.170029  2.132684e+10  0.807506                 0.0       0.0
# 248 -0.200748  2.135377e+10  0.786671                 0.0       0.0
# 249 -0.131947  2.135377e+10  0.797791                 0.0       0.0
# 250  0.367023  2.137436e+10  0.812369                 0.0       0.0
# 251  0.982037  2.139339e+10  0.809608                 0.0       0.0
#
#      pred_close right_call? real_trend
# 247   36.800823         yes       down
# 248   37.180161          no         up
# 249   37.241634          no          -
# 250   38.165600          no         up
# 251   38.610947          no         up

# %%
# viewing shares and value balance
comp_account.view_balance()
# Out:
# CSCO account has 0 shares remaining.
# CSCO account has $ 0 shares on hand value.
# CSCO account has $ 51755.63 remaining.
# ------------------------------
# 51755.629198923925

# %%
# get last row index and close price then multiply by shares_balance
if comp_account.share_balance == 0:
    closing_value_balance = 0
else:
    last_index = audit_trans_df.index.max()
    closing_value_balance = comp_account.share_balance * audit_trans_df.loc[last_index].Close
print(f'{test_comp} position closing value = {closing_value_balance}')
# Out:
# CSCO position closing value = 0

# %%
# Future value calculation
PV = acct_start_bal  # prevent value
r = 1.5  # assume 1.5% fixed deposit rate per annum which is very rare
n = len(pd.date_range(start=backtest_start, end=backtest_end, freq='Y')) #Number of periods in years
if n == 0:
    n = 1 # rounding up to 1 yr cos freq='Y' may return a zero

FV = PV*(1+r/100)**n

print(f'===== COMPARISON WITH BANKING =====')
print(f'Putting $ {PV} in bank for {r}% interest per year compounded over {n} yr returns $ {round(FV,2)}')
# Out:
# ===== COMPARISON WITH BANKING =====
# Putting $ 50000 in bank for 1.5% interest per year compounded over 1 yr returns $ 50750.0

# %% [markdown]
# ### Exporting trade results

# %%
# create a df to store comp results
result_list = ['Short Term Simple Strategy',                                # strategy name
               backtest_start,                                              # start date of backtest
               backtest_end,                                                # end date of backtest
               n_per_in,                                                    # no. of look back periods
               n_per_out,                                                   # no. of periods to predict
               all_trans_record_df.shape[0],                                # no. of trade days
               n,                                                           # periods rounded up in yrs
               len(all_trans_record_df[all_trans_record_df.qty!=0].index),  # Total trades conducted
               acct_start_bal,                                              # Account starting balance
               comp_account.value_balance,                                  # Account ending balance               
               comp_account.share_balance,                                  # Account share balance
               closing_value_balance,                                       # Account close value               
               
               # Profit/Loss
               (comp_account.value_balance + closing_value_balance) - acct_start_bal,
               
               # Total Percentage return (whole period)
               (((comp_account.value_balance + closing_value_balance) - acct_start_bal) / acct_start_bal)*100,
               
               # Percentage return per yr
               ((((comp_account.value_balance + closing_value_balance) - acct_start_bal) / acct_start_bal)/n)*100,
               round(FV,2),                                                 # Banking returns               
               rmse,                                                        # RMSE
               right_call,                                                  # Number of right calls
               right_call_pct,                                              # Right calls %
               wrong_call,                                                  # Number of right calls
               wrong_call_pct]                                              # Wrong calls %

desc_list = ['Strategy Name',
             'Trade actions from',
             'Trade actions to',
             'Look back periods',
             'Prediction periods',
             'Total number of trade days',
             'In yrs rounded up',
             'Total trades conducted',
             'Account starting balance',
             'Account ending balance',             
             'Account share balance',
             'Account Close Value',  
             'Profit/Loss',             
             'Total Percentage return (whole period)',
             'Percentage return per yr',
             'Banking returns',
             'RMSE',
             'Number of right calls',
             'Right calls %',
             'Number of wrong calls',
             'Wrong calls %']

blank_df = pd.DataFrame(desc_list, columns=['Description'])
one_result_df = pd.DataFrame(result_list, columns=[test_comp])
one_result_df = pd.concat([blank_df, one_result_df], axis=1)

# export to csv
one_result_df.to_csv(PERF_DIR+test_comp+'_1yr_strategy_account_result.csv', index=False)
one_result_df
# Out:
#                                Description                        CSCO
# 0                            Strategy Name  Short Term Simple Strategy
# 1                       Trade actions from         2019-10-09 00:00:00
# 2                         Trade actions to         2020-10-08 00:00:00
# 3                        Look back periods                          60
# 4                       Prediction periods                           1
# 5               Total number of trade days                         252
# 6                        In yrs rounded up                           1
# 7                   Total trades conducted                           4
# 8                 Account starting balance                       50000
# 9                   Account ending balance                51755.629199
# 10                   Account share balance                           0
# 11                     Account Close Value                           0
# 12                             Profit/Loss                 1755.629199
# 13  Total Percentage return (whole period)                    3.511258
# 14                Percentage return per yr                    3.511258
# 15                         Banking returns                50750.000000
# 16                                    RMSE                    0.613056
# 17                   Number of right calls                         142
# 18                           Right calls %                   56.349206
# 19                   Number of wrong calls                         110
# 20                           Wrong calls %                   43.650794

# %% [markdown]
# ## END OF NOTEBOOK
#
# We shall move on the the Modeling_Execution_with_Tuning notebook.
